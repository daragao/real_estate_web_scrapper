# %%
import requests
from bs4 import BeautifulSoup
import textwrap
from datetime import datetime
import json
import urllib

# %%
with open("scrap.json") as json_file:
    scrap_json = json.load(json_file)
print('Loaded scrap json:\n\tUID: {}'.format(scrap_json['uid']))
# Out:
# Loaded scrap json:
# 	UID: 55c5fd9dadafwmbu5lzwmd2vx5d2agxggm894hqnht8

# %% [markdown]
# ## Ad scrapping

# %%
def json_to_cookie(cookie_json):
    return '; '.join(['{}={}'.format(k,v) for k, v in cookie_json.items()])
#print(cookie_str, new_cookie_str)

#print compare
def compare_print(a, b):
    print('{:>55} | {:<55}'.format('A','B'))
    print('-'*113)
    for i in range(len(a)):
        a_el = ''
        b_el = ''
        if(len(a) > i):
            a_el = a[i]
        if(len(b) > i):
            b_el = b[i]
        print('{:<55} | {:<55}'.format(a_el,b_el))

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'cookie': json_to_cookie(scrap_json['cookie'])
}

# %%
articles = []

host = 'https://www.idealista.pt'
path = 'en/comprar-casas'
region = 'lisboa'
params = ['com-tamanho-min_100','publicado_ultimas-48-horas']
url = '/' + '/'.join([path,region,','.join(params)])

i = 0
while url:
    i += 1
    url = host + url
    print('{}) Request URL: {}'.format(i, url))
    
    req = requests.get(url, headers)
    if(req.status_code != 200):
        print('{}) HTTP Code {}\n\tBody: {}'.format(i, req.status_code,req.text))
        break
    
    soup = BeautifulSoup(req.content, 'html.parser')
    
    articles += soup.find_all('article')
    
    print('\tArticles/Ads found: {}'.format(len(articles)))
    pagination = soup.find('div', 'pagination')

    next_page_tag = pagination.find('a', 'icon-arrow-right-after')
    url = next_page_tag.get('href') if next_page_tag else None
# Out:
# 1) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas
# 	Articles/Ads found: 32
# 2) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-2
# 	Articles/Ads found: 64
# 3) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-3
# 	Articles/Ads found: 96
# 4) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-4
# 	Articles/Ads found: 128
# 5) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-5
# 	Articles/Ads found: 135

# %%
#print(articles[0].prettify())

items = []
for ad in articles:
    # .info-data-price
    if('adv' in ad.attrs['class']):
        continue
    item_price = ad.find('span', class_='item-price')
    item_detail = ad.find_all('span', class_='item-detail')
    item_link = ad.find('a', class_='item-link')
    item_title = item_link.get('title')
    item_id = ad.get('data-adid')
    
    price = int(item_price.get_text()[:-1].replace(',',''))
    address = urllib.parse.quote(item_title[item_title.find(' in ')+4:]) if item_title.find(' in ') != - 1 else item_title
    size = int(item_detail[1].get_text()[:-3].replace(',','')) if len(item_detail) > 1 else print('{} Failed to fetch area!'.format(item_id))
    item_url = '{}{}'.format(host,item_link.get('href'))

    items.append({
        'price': price,
        'address': address,
        'id': item_id,
        'size': size,
        'url': item_url
    })
    #print(json.dumps(items_dict[item_id], indent=4, sort_keys=True))
print('Ads parsed: {}'.format(len(items)))
# Out:
# Ads parsed: 126

# %%
time_format = '%d-%m-%Y_%H:%M:%S_scrap'
data_path = './data_scrap'

now = datetime.now()
s2 = now.strftime(time_format)

f = open(data_path + '/' + s2 + ".json","w")
f.write(json.dumps(items))
f.close()

# %% [markdown]
# ## Ad GeoLocation (scrapped from Idealista)

# %%
import urllib
# TODO go around the map taking the places
params_dict = dict(
    locationUri='lisboa',
    typology='1',
    operation='1',
    zoom='5',
    northEast='54.17960751741163,16.15620517730715',
    southWest='19.08984486221779,-34.46879482269287',
    uid=scrap_json['uid'],
    adfilter_pricemin='default',
    adfilter_price='700000',
    adfilter_area='100',
    adfilter_areamax='default',
    adfilter_published='default'
)
params_dict['solo-favoritos'] = 'false'
params = urllib.parse.urlencode(params_dict, doseq=True)

host = 'https://www.idealista.pt'
path = '/ajax/listingcontroller/listingmapajax.ajax'

new_url = '{}{}?{}'.format(host,path,params)


req = requests.get(new_url, headers)
print(req)
ajax_listing_json = req.json()
json_resp = ajax_listing_json['jsonResponse']

print(json_resp.keys(), len(json_resp['map']['items']))

print(len(json_resp['map']['items']), json_resp['listingTotalResults'])
for geo in json_resp['map']['items']:
    print(geo['adId'])
# Out:
# <Response [200]>
# dict_keys(['valueH1', 'description', 'total', 'result', 'errorMessage', 'searchFeaturesPhrase', 'searchPhrase', 'howmany', 'search', 'breadcrumbUrlValue', 'breadcrumbUrlAllMunicipalitiesLevel', 'mapSearchUrl', 'listingSearchUrl', 'rentListingSearchUrl', 'saleListingSearchUrlMobile', 'newDevelopmentUrlMobile', 'newDevelopmentUrl', 'saleListingSearchUrl', 'rentListingSearchUrlMobile', 'pagetarget', 'searchTotalsUrl', 'searchWithoutFilters', 'listingTotalResults', 'listingPriceByArea', 'map', 'existAlert']) 1300
# 1300 4.110
# 30579297
# 30588445
# 30574563
# 30449665
# 30555916
# 30502116
# 29973505
# 30410973
# 30578514
# 30500469
# 30320596
# 30466689
# 30495942
# 30598207
# 30421636
# 29162771
# 29805147
# 30236328
# 30502176
# 30201596
# 30300785
# 29839441
# 30041316
# 30454549
# 30581620
# 30531663
# 28722785
# 30346263
# 30272272
# 30360956
# 30360952
# 30336240
# 30515559
# 30524931
# 29130767
# 30089300
# 29743272
# 30215749
# 30566607
# 30450654
# 28913068
# 30393162
# 30411086
# 30396586
# 30396805
# 30391883
# 30391850
# 30391873
# 30341029
# 30331774
# 30323175
# 30483168
# 30212192
# 30505267
# 30508519
# 30456239
# 29369283
# 29663193
# 29928128
# 30430613
# 30247975
# 30189798
# 30519376
# 30252214
# 30531506
# 30271970
# 30578969
# 30279701
# 30212208
# 30177012
# 30177544
# 30509477
# 30171998
# 30171994
# 30172453
# 30172475
# 30171995
# 30171989
# 30184103
# 30212191
# 30448223
# 30255514
# 30199936
# 30105276
# 30190559
# 30190564
# 30307138
# 29489625
# 30307170
# 30566856
# 30464910
# 30391604
# 29496954
# 29893410
# 30569710
# 29397618
# 29976275
# 30588519
# 30615193
# 30472625
# 29096213
# 30561417
# 30595296
# 30273370
# 30306066
# 30306282
# 30460078
# 30306603
# 30306627
# 30306507
# 30305974
# 30399813
# 30510871
# 30405287
# 30598606
# 30405294
# 30405286
# 30405298
# 30405281
# 29925821
# 30425965
# 30300923
# 30598199
# 30574059
# 30572068
# 30525004
# 30446469
# 29976479
# 30575417
# 30454607
# 29866695
# 30184564
# 30464964
# 29500204
# 30345226
# 28178685
# 30407935
# 28974239
# 30244389
# 29703749
# 30300247
# 30010967
# 29675019
# 28877660
# 30142283
# 29881105
# 30501421
# 30184563
# 30624023
# 30609050
# 30569625
# 30235962
# 30539974
# 29978297
# 29972463
# 30523012
# 30540478
# 30220967
# 30220979
# 30230811
# 30251729
# 30437754
# 30525934
# 30230804
# 30564151
# 29379502
# 30342705
# 30530371
# 30427480
# 30599127
# 30330970
# 30509676
# 30570425
# 30000339
# 30570397
# 30387624
# 30387608
# 30622484
# 30383444
# 30211546
# 30548255
# 30396139
# 30557203
# 30449550
# 30618810
# 30610427
# 29813319
# 30187320
# 30596798
# 30191484
# 30453569
# 30610383
# 30534395
# 30133763
# 30133761
# 30074909
# 30425950
# 30496798
# 30483591
# 30416696
# 29379504
# 30317157
# 30592392
# 30473430
# 30342652
# 30517781
# 30295792
# 30387605
# 29710053
# 29152229
# 30305202
# 30401888
# 29451633
# 30359419
# 30488674
# 30401877
# 30305204
# 30295826
# 30433779
# 30392639
# 30305205
# 30392641
# 30295825
# 30305203
# 30610344
# 29686070
# 30530361
# 28884161
# 28884159
# 30326805
# 30493898
# 30314454
# 29873794
# 30440666
# 30610370
# 30162986
# 30463126
# 30331003
# 30573431
# 30484858
# 30151822
# 30567580
# 30245130
# 29562145
# 29008621
# 30483563
# 30534299
# 30570416
# 30544948
# 30564148
# 29562146
# 30544932
# 30314457
# 30191471
# 30427481
# 30577895
# 30548197
# 30048819
# 30557163
# 30599171
# 30573432
# 30301306
# 30295808
# 30557158
# 30554614
# 29333133
# 30057547
# 30111016
# 28289176

# %% [markdown]
# ## Join Ad and GeoLocation

# %%
items_dict = {}
for it in items:
    items_dict[it['id']] = it

geo_dict = {}
for geo in json_resp['map']['items']:
    geo_dict[geo['adId']] = geo
    
    if str(geo['adId']) in items_dict:
        items_dict[str(geo['adId'])]['geo'] = { 'latitude': geo['latitude'], 'longitude': geo['longitude'] }
        #print(items_dict[str(geo['adId'])])
print(json.dumps(items_dict, indent=4, sort_keys=True))
# Out:
# {
#     "30114049": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30114049",
#         "price": 1050000,
#         "size": 172,
#         "url": "https://www.idealista.pt/en/imovel/30114049/"
#     },
#     "30231156": {
#         "address": "Saldanha%20-%20Picoas%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30231156",
#         "price": 1398000,
#         "size": 222,
#         "url": "https://www.idealista.pt/en/imovel/30231156/"
#     },
#     "30247992": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30247992",
#         "price": 2400000,
#         "size": 763,
#         "url": "https://www.idealista.pt/en/imovel/30247992/"
#     },
#     "30365401": {
#         "address": "avenida%20da%20Rep%C3%BAblica%2C%20Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30365401",
#         "price": 350000,
#         "size": 127,
#         "url": "https://www.idealista.pt/en/imovel/30365401/"
#     },
#     "30588773": {
#         "address": "Saldanha%20-%20Picoas%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30588773",
#         "price": 1290000,
#         "size": 260,
#         "url": "https://www.idealista.pt/en/imovel/30588773/"
#     },
#     "30605391": {
#         "address": "Alvalade%2C%20Alvalade",
#         "id": "30605391",
#         "price": 899900,
#         "size": 157,
#         "url": "https://www.idealista.pt/en/imovel/30605391/"
#     },
#     "30605547": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30605547",
#         "price": 850000,
#         "size": 230,
#         "url": "https://www.idealista.pt/en/imovel/30605547/"
#     },
#     "30609050": {
#         "address": "Ajuda%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7069529,
#             "longitude": -9.1999029
#         },
#         "id": "30609050",
#         "price": 525000,
#         "size": 230,
#         "url": "https://www.idealista.pt/en/imovel/30609050/"
#     },
#     "30617518": {
#         "address": "rua%20Doutor%20Bastos%20Gon%C3%A7alves%2C%201%2C%20S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30617518",
#         "price": 995000,
#         "size": 264,
#         "url": "https://www.idealista.pt/en/imovel/30617518/"
#     },
#     "30618264": {
#         "address": "T3 flat, campo Grande, Campo Grande, Alvalade",
#         "id": "30618264",
#         "price": 850000,
#         "size": 190,
#         "url": "https://www.idealista.pt/en/imovel/30618264/"
#     },
#     "30618334": {
#         "address": "Bairro%20Alto%20-%20Encarna%C3%A7%C3%A3o%2C%20Miseric%C3%B3rdia",
#         "id": "30618334",
#         "price": 520000,
#         "size": 101,
#         "url": "https://www.idealista.pt/en/imovel/30618334/"
#     },
#     "30618445": {
#         "address": "Alameda%20-%20Pra%C3%A7a%20do%20Chile%20-%20Almirante%20Reis%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30618445",
#         "price": 700000,
#         "size": 403,
#         "url": "https://www.idealista.pt/en/imovel/30618445/"
#     },
#     "30618502": {
#         "address": "Restelo%2C%20Bel%C3%A9m",
#         "id": "30618502",
#         "price": 515000,
#         "size": 108,
#         "url": "https://www.idealista.pt/en/imovel/30618502/"
#     },
#     "30618652": {
#         "address": "Gra%C3%A7a%2C%20S%C3%A3o%20Vicente",
#         "geo": {
#             "latitude": 38.715696,
#             "longitude": -9.129356
#         },
#         "id": "30618652",
#         "price": 285000,
#         "size": 134,
#         "url": "https://www.idealista.pt/en/imovel/30618652/"
#     },
#     "30618808": {
#         "address": "Alvalade%2C%20Alvalade",
#         "id": "30618808",
#         "price": 899900,
#         "size": 168,
#         "url": "https://www.idealista.pt/en/imovel/30618808/"
#     },
#     "30618810": {
#         "address": "Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "geo": {
#             "latitude": 38.732397,
#             "longitude": -9.1303414
#         },
#         "id": "30618810",
#         "price": 549900,
#         "size": 148,
#         "url": "https://www.idealista.pt/en/imovel/30618810/"
#     },
#     "30618974": {
#         "address": "Anjos%2C%20Arroios",
#         "geo": {
#             "latitude": 38.7269222,
#             "longitude": -9.1316859
#         },
#         "id": "30618974",
#         "price": 525000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30618974/"
#     },
#     "30619104": {
#         "address": "T3 flat, Av Infante Santo, Prazeres, Estrela",
#         "geo": {
#             "latitude": 38.7059151,
#             "longitude": -9.1664864
#         },
#         "id": "30619104",
#         "price": 525000,
#         "size": 115,
#         "url": "https://www.idealista.pt/en/imovel/30619104/"
#     },
#     "30619106": {
#         "address": "avenida%20Estados%20Unidos%20da%20Am%C3%A9rica%2C%20Campo%20Grande%2C%20Alvalade",
#         "id": "30619106",
#         "price": 998000,
#         "size": 252,
#         "url": "https://www.idealista.pt/en/imovel/30619106/"
#     },
#     "30619684": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30619684",
#         "price": 440000,
#         "size": 117,
#         "url": "https://www.idealista.pt/en/imovel/30619684/"
#     },
#     "30619850": {
#         "address": "Santa%20Engr%C3%A1cia%2C%20S%C3%A3o%20Vicente",
#         "id": "30619850",
#         "price": 385000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30619850/"
#     },
#     "30619986": {
#         "address": "rua%20Carrilho%20Videira%2C%20Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30619986",
#         "price": 549900,
#         "size": 150,
#         "url": "https://www.idealista.pt/en/imovel/30619986/"
#     },
#     "30620146": {
#         "address": "rua%20de%20Campolide%2C%20NN%2C%20Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30620146",
#         "price": 1800000,
#         "size": 682,
#         "url": "https://www.idealista.pt/en/imovel/30620146/"
#     },
#     "30620182": {
#         "address": "rua%20C%C3%A2ndido%20Figueiredo%2C%20NN%2C%20S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30620182",
#         "price": 495000,
#         "size": 135,
#         "url": "https://www.idealista.pt/en/imovel/30620182/"
#     },
#     "30620208": {
#         "address": "Santos-o-Velho%20-%20Madragoa%2C%20Estrela",
#         "id": "30620208",
#         "price": 1300000,
#         "size": 254,
#         "url": "https://www.idealista.pt/en/imovel/30620208/"
#     },
#     "30620227": {
#         "address": "rua%20Quatro%2C%20Alto%20do%20Lumiar%2C%20Lumiar",
#         "id": "30620227",
#         "price": 550000,
#         "size": 134,
#         "url": "https://www.idealista.pt/en/imovel/30620227/"
#     },
#     "30620238": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30620238",
#         "price": 895000,
#         "size": 261,
#         "url": "https://www.idealista.pt/en/imovel/30620238/"
#     },
#     "30620257": {
#         "address": "Castelo%20-%20Mouraria%2C%20Santa%20Maria%20Maior",
#         "id": "30620257",
#         "price": 155000,
#         "size": 6715,
#         "url": "https://www.idealista.pt/en/imovel/30620257/"
#     },
#     "30620260": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30620260",
#         "price": 1990000,
#         "size": 379,
#         "url": "https://www.idealista.pt/en/imovel/30620260/"
#     },
#     "30620302": {
#         "address": "Santa%20Engr%C3%A1cia%2C%20S%C3%A3o%20Vicente",
#         "id": "30620302",
#         "price": 994500,
#         "size": 190,
#         "url": "https://www.idealista.pt/en/imovel/30620302/"
#     },
#     "30620309": {
#         "address": "S%C3%A3o%20Mamede%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620309",
#         "price": 1350000,
#         "size": 320,
#         "url": "https://www.idealista.pt/en/imovel/30620309/"
#     },
#     "30620316": {
#         "address": "rua%20Professor%20Carlos%20Teixeira%2C%20Telheiras%2C%20Lumiar",
#         "id": "30620316",
#         "price": 630000,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30620316/"
#     },
#     "30620374": {
#         "address": "rua%20Virg%C3%ADlio%20Martinho%2C%20Carnide%2C%20Lisboa",
#         "id": "30620374",
#         "price": 375000,
#         "size": 115,
#         "url": "https://www.idealista.pt/en/imovel/30620374/"
#     },
#     "30620380": {
#         "address": "avenida%20Cidade%20de%20Louren%C3%A7o%20Marques%2C%20NN%2C%20Olivais%2C%20Lisboa",
#         "id": "30620380",
#         "price": 349000,
#         "size": 118,
#         "url": "https://www.idealista.pt/en/imovel/30620380/"
#     },
#     "30620443": {
#         "address": "rua%20de%20Santa%20Marta%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620443",
#         "price": 840000,
#         "size": 131,
#         "url": "https://www.idealista.pt/en/imovel/30620443/"
#     },
#     "30620447": {
#         "address": "rua%20Rodrigo%20da%20Fonseca%2C%20NN%2C%20S%C3%A3o%20Mamede%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620447",
#         "price": 757000,
#         "size": 103,
#         "url": "https://www.idealista.pt/en/imovel/30620447/"
#     },
#     "30620526": {
#         "address": "Areeiro%2C%20Lisboa",
#         "id": "30620526",
#         "price": 395000,
#         "size": 107,
#         "url": "https://www.idealista.pt/en/imovel/30620526/"
#     },
#     "30620556": {
#         "address": "Marvila%2C%20Lisboa",
#         "id": "30620556",
#         "price": 950000,
#         "size": 276,
#         "url": "https://www.idealista.pt/en/imovel/30620556/"
#     },
#     "30620649": {
#         "address": "estrada%20de%20Benfica%2C%20NN%2C%20Arneiros%20-%20Avenida%20Uruguai%20-%20Charquinho%2C%20Benfica",
#         "id": "30620649",
#         "price": 799000,
#         "size": 160,
#         "url": "https://www.idealista.pt/en/imovel/30620649/"
#     },
#     "30620665": {
#         "address": "T3 flat, Pra\u00e7a Bernardo Santareno, NN, Areeiro, Lisboa",
#         "id": "30620665",
#         "price": 550000,
#         "size": 170,
#         "url": "https://www.idealista.pt/en/imovel/30620665/"
#     },
#     "30620668": {
#         "address": "avenida%20Duque%20de%20Loul%C3%A9%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620668",
#         "price": 780000,
#         "size": 116,
#         "url": "https://www.idealista.pt/en/imovel/30620668/"
#     },
#     "30620669": {
#         "address": "avenida%20Duque%20de%20Loul%C3%A9%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620669",
#         "price": 780000,
#         "size": 115,
#         "url": "https://www.idealista.pt/en/imovel/30620669/"
#     },
#     "30620670": {
#         "address": "avenida%20Duque%20de%20Loul%C3%A9%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620670",
#         "price": 795000,
#         "size": 116,
#         "url": "https://www.idealista.pt/en/imovel/30620670/"
#     },
#     "30620671": {
#         "address": "avenida%20Duque%20de%20Loul%C3%A9%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620671",
#         "price": 815000,
#         "size": 115,
#         "url": "https://www.idealista.pt/en/imovel/30620671/"
#     },
#     "30620673": {
#         "address": "avenida%20Duque%20de%20Loul%C3%A9%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620673",
#         "price": 815000,
#         "size": 116,
#         "url": "https://www.idealista.pt/en/imovel/30620673/"
#     },
#     "30620675": {
#         "address": "avenida%20Duque%20de%20Loul%C3%A9%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620675",
#         "price": 830000,
#         "size": 115,
#         "url": "https://www.idealista.pt/en/imovel/30620675/"
#     },
#     "30620678": {
#         "address": "avenida%20Duque%20de%20Loul%C3%A9%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620678",
#         "price": 830000,
#         "size": 116,
#         "url": "https://www.idealista.pt/en/imovel/30620678/"
#     },
#     "30620679": {
#         "address": "avenida%20Duque%20de%20Loul%C3%A9%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620679",
#         "price": 1060000,
#         "size": 155,
#         "url": "https://www.idealista.pt/en/imovel/30620679/"
#     },
#     "30620680": {
#         "address": "avenida%20Duque%20de%20Loul%C3%A9%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620680",
#         "price": 1100000,
#         "size": 162,
#         "url": "https://www.idealista.pt/en/imovel/30620680/"
#     },
#     "30620682": {
#         "address": "largo%20de%20Andaluz%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620682",
#         "price": 1060000,
#         "size": 165,
#         "url": "https://www.idealista.pt/en/imovel/30620682/"
#     },
#     "30620683": {
#         "address": "largo%20de%20Andaluz%2C%20NN%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30620683",
#         "price": 915000,
#         "size": 136,
#         "url": "https://www.idealista.pt/en/imovel/30620683/"
#     },
#     "30620733": {
#         "address": "avenida%20Almirante%20Reis%2C%20NN%2C%20Alameda%20-%20Pra%C3%A7a%20do%20Chile%20-%20Almirante%20Reis%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30620733",
#         "price": 347500,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30620733/"
#     },
#     "30621134": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30621134",
#         "price": 810000,
#         "size": 141,
#         "url": "https://www.idealista.pt/en/imovel/30621134/"
#     },
#     "30621175": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30621175",
#         "price": 1990000,
#         "size": 380,
#         "url": "https://www.idealista.pt/en/imovel/30621175/"
#     },
#     "30621182": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30621182",
#         "price": 650000,
#         "size": 145,
#         "url": "https://www.idealista.pt/en/imovel/30621182/"
#     },
#     "30621249": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30621249",
#         "price": 1100000,
#         "size": 242,
#         "url": "https://www.idealista.pt/en/imovel/30621249/"
#     },
#     "30621282": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30621282",
#         "price": 1090000,
#         "size": 248,
#         "url": "https://www.idealista.pt/en/imovel/30621282/"
#     },
#     "30621335": {
#         "address": "Areeiro%2C%20Lisboa",
#         "id": "30621335",
#         "price": 695000,
#         "size": 165,
#         "url": "https://www.idealista.pt/en/imovel/30621335/"
#     },
#     "30621372": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30621372",
#         "price": 1390000,
#         "size": 230,
#         "url": "https://www.idealista.pt/en/imovel/30621372/"
#     },
#     "30621376": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30621376",
#         "price": 750000,
#         "size": 101,
#         "url": "https://www.idealista.pt/en/imovel/30621376/"
#     },
#     "30621762": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30621762",
#         "price": 1590000,
#         "size": 550,
#         "url": "https://www.idealista.pt/en/imovel/30621762/"
#     },
#     "30621843": {
#         "address": "Alvalade%2C%20Alvalade",
#         "id": "30621843",
#         "price": 899900,
#         "size": 218,
#         "url": "https://www.idealista.pt/en/imovel/30621843/"
#     },
#     "30621893": {
#         "address": "Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30621893",
#         "price": 549900,
#         "size": 148,
#         "url": "https://www.idealista.pt/en/imovel/30621893/"
#     },
#     "30622078": {
#         "address": "Baixa%2C%20Santa%20Maria%20Maior",
#         "id": "30622078",
#         "price": 990000,
#         "size": 140,
#         "url": "https://www.idealista.pt/en/imovel/30622078/"
#     },
#     "30622095": {
#         "address": "Restelo%2C%20Bel%C3%A9m",
#         "id": "30622095",
#         "price": 1600000,
#         "size": 266,
#         "url": "https://www.idealista.pt/en/imovel/30622095/"
#     },
#     "30622105": {
#         "address": "S%C3%A3o%20Vicente%20de%20Fora%2C%20S%C3%A3o%20Vicente",
#         "id": "30622105",
#         "price": 195000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30622105/"
#     },
#     "30622137": {
#         "address": "Prazeres%2C%20Estrela",
#         "geo": {
#             "latitude": 38.7055099,
#             "longitude": -9.1675121
#         },
#         "id": "30622137",
#         "price": 525000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30622137/"
#     },
#     "30622310": {
#         "address": "Lapa%2C%20Estrela",
#         "id": "30622310",
#         "price": 4200000,
#         "size": 603,
#         "url": "https://www.idealista.pt/en/imovel/30622310/"
#     },
#     "30622328": {
#         "address": "Alvalade%2C%20Alvalade",
#         "id": "30622328",
#         "price": 899900,
#         "size": 291,
#         "url": "https://www.idealista.pt/en/imovel/30622328/"
#     },
#     "30622484": {
#         "address": "Santa%20Clara%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7811755,
#             "longitude": -9.1475873
#         },
#         "id": "30622484",
#         "price": 420000,
#         "size": 166,
#         "url": "https://www.idealista.pt/en/imovel/30622484/"
#     },
#     "30622492": {
#         "address": "Igreja%20-%20Mercado%20-%20Pedralvas%2C%20Benfica",
#         "id": "30622492",
#         "price": 650000,
#         "size": 190,
#         "url": "https://www.idealista.pt/en/imovel/30622492/"
#     },
#     "30622511": {
#         "address": "estrada%20do%20Calhariz%20de%20Benfica%2C%20Fonte%20Nova%20-%20Monsanto%2C%20Benfica",
#         "id": "30622511",
#         "price": 550000,
#         "size": 131,
#         "url": "https://www.idealista.pt/en/imovel/30622511/"
#     },
#     "30622525": {
#         "address": "Castelo%20-%20Mouraria%2C%20Santa%20Maria%20Maior",
#         "id": "30622525",
#         "price": 900000,
#         "size": 192,
#         "url": "https://www.idealista.pt/en/imovel/30622525/"
#     },
#     "30622526": {
#         "address": "Castelo%20-%20Mouraria%2C%20Santa%20Maria%20Maior",
#         "id": "30622526",
#         "price": 1350000,
#         "size": 191,
#         "url": "https://www.idealista.pt/en/imovel/30622526/"
#     },
#     "30622599": {
#         "address": "Prazeres%2C%20Estrela",
#         "id": "30622599",
#         "price": 525000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30622599/"
#     },
#     "30622614": {
#         "address": "rua%20Gil%20Vicente%2C%20Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30622614",
#         "price": 650000,
#         "size": 132,
#         "url": "https://www.idealista.pt/en/imovel/30622614/"
#     },
#     "30622681": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30622681",
#         "price": 510000,
#         "size": 174,
#         "url": "https://www.idealista.pt/en/imovel/30622681/"
#     },
#     "30622887": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30622887",
#         "price": 375000,
#         "size": 155,
#         "url": "https://www.idealista.pt/en/imovel/30622887/"
#     },
#     "30622892": {
#         "address": "rua%20Joaquim%20Casimiro%2C%20NN%2C%20Prazeres%2C%20Estrela",
#         "id": "30622892",
#         "price": 315000,
#         "size": 127,
#         "url": "https://www.idealista.pt/en/imovel/30622892/"
#     },
#     "30622970": {
#         "address": "rua%20Actor%20Vale%2C%20NN%2C%20Bairro%20dos%20Actores%20-%20Bar%C3%A3o%20Sabrosa%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30622970",
#         "price": 373000,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30622970/"
#     },
#     "30622971": {
#         "address": "rua%20Carvalho%20Ara%C3%BAjo%2C%20NN%2C%20Alameda%20-%20Pra%C3%A7a%20do%20Chile%20-%20Almirante%20Reis%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30622971",
#         "price": 545000,
#         "size": 169,
#         "url": "https://www.idealista.pt/en/imovel/30622971/"
#     },
#     "30622985": {
#         "address": "rua%20Francisco%20Franco%2C%20NN%2C%20S%C3%A3o%20Jo%C3%A3o%20de%20Brito%2C%20Alvalade",
#         "id": "30622985",
#         "price": 480000,
#         "size": 143,
#         "url": "https://www.idealista.pt/en/imovel/30622985/"
#     },
#     "30623071": {
#         "address": "Campo%20de%20Ourique%2C%20Lisboa",
#         "id": "30623071",
#         "price": 950000,
#         "size": 217,
#         "url": "https://www.idealista.pt/en/imovel/30623071/"
#     },
#     "30623073": {
#         "address": "Campo%20de%20Ourique%2C%20Lisboa",
#         "id": "30623073",
#         "price": 1150000,
#         "size": 217,
#         "url": "https://www.idealista.pt/en/imovel/30623073/"
#     },
#     "30623238": {
#         "address": "rua%20Carrilho%20Videira%2C%20Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30623238",
#         "price": 549900,
#         "size": 139,
#         "url": "https://www.idealista.pt/en/imovel/30623238/"
#     },
#     "30623267": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30623267",
#         "price": 690000,
#         "size": 132,
#         "url": "https://www.idealista.pt/en/imovel/30623267/"
#     },
#     "30623308": {
#         "address": "Restelo%2C%20Bel%C3%A9m",
#         "id": "30623308",
#         "price": 1599000,
#         "size": 318,
#         "url": "https://www.idealista.pt/en/imovel/30623308/"
#     },
#     "30623413": {
#         "address": "Arneiros%20-%20Avenida%20Uruguai%20-%20Charquinho%2C%20Benfica",
#         "id": "30623413",
#         "price": 300000,
#         "size": 126,
#         "url": "https://www.idealista.pt/en/imovel/30623413/"
#     },
#     "30623507": {
#         "address": "Gra%C3%A7a%2C%20S%C3%A3o%20Vicente",
#         "id": "30623507",
#         "price": 285000,
#         "size": 197,
#         "url": "https://www.idealista.pt/en/imovel/30623507/"
#     },
#     "30623668": {
#         "address": "rua%20Lu%C3%ADs%20de%20Cam%C3%B5es%2C%20102%2C%20Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30623668",
#         "price": 415000,
#         "size": 107,
#         "url": "https://www.idealista.pt/en/imovel/30623668/"
#     },
#     "30623677": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30623677",
#         "price": 1990000,
#         "size": 381,
#         "url": "https://www.idealista.pt/en/imovel/30623677/"
#     },
#     "30623780": {
#         "address": "Merc%C3%AAs%2C%20Miseric%C3%B3rdia",
#         "id": "30623780",
#         "price": 625000,
#         "size": 107,
#         "url": "https://www.idealista.pt/en/imovel/30623780/"
#     },
#     "30623885": {
#         "address": "Alto%20do%20Lumiar%2C%20Lumiar",
#         "id": "30623885",
#         "price": 635375,
#         "size": 322,
#         "url": "https://www.idealista.pt/en/imovel/30623885/"
#     },
#     "30623899": {
#         "address": "T4 flat, Av. Cidade de Louren\u00e7o Marques, Olivais, Lisboa",
#         "id": "30623899",
#         "price": 349000,
#         "size": 118,
#         "url": "https://www.idealista.pt/en/imovel/30623899/"
#     },
#     "30623903": {
#         "address": "T2 flat, campo M\u00e1rtires de P\u00e1tria, Pena, Arroios",
#         "id": "30623903",
#         "price": 665000,
#         "size": 176,
#         "url": "https://www.idealista.pt/en/imovel/30623903/"
#     },
#     "30623919": {
#         "address": "Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30623919",
#         "price": 549900,
#         "size": 153,
#         "url": "https://www.idealista.pt/en/imovel/30623919/"
#     },
#     "30623952": {
#         "address": "rua%20de%20S.%20Bernardo%2C%20Lapa%2C%20Estrela",
#         "id": "30623952",
#         "price": 1800000,
#         "size": 175,
#         "url": "https://www.idealista.pt/en/imovel/30623952/"
#     },
#     "30624019": {
#         "address": "rua%20Sousa%20Lopes%2C%20Entrecampos%2C%20Avenidas%20Novas",
#         "id": "30624019",
#         "price": 725000,
#         "size": 187,
#         "url": "https://www.idealista.pt/en/imovel/30624019/"
#     },
#     "30624023": {
#         "address": "Restelo%2C%20Bel%C3%A9m",
#         "geo": {
#             "latitude": 38.6971639,
#             "longitude": -9.211595
#         },
#         "id": "30624023",
#         "price": 370000,
#         "size": 104,
#         "url": "https://www.idealista.pt/en/imovel/30624023/"
#     },
#     "30624034": {
#         "address": "rua%20Antero%20de%20Figueiredo%2C%20Alvalade%2C%20Alvalade",
#         "geo": {
#             "latitude": 38.7485406,
#             "longitude": -9.1389723
#         },
#         "id": "30624034",
#         "price": 430000,
#         "size": 140,
#         "url": "https://www.idealista.pt/en/imovel/30624034/"
#     },
#     "30624059": {
#         "address": "T5 flat, Almirante Reis, Anjos, Arroios",
#         "id": "30624059",
#         "price": 340000,
#         "size": 140,
#         "url": "https://www.idealista.pt/en/imovel/30624059/"
#     },
#     "30624065": {
#         "address": "rua%20Carvalho%20Ara%C3%BAjo%2C%20Alameda%20-%20Pra%C3%A7a%20do%20Chile%20-%20Almirante%20Reis%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "geo": {
#             "latitude": 38.7346477,
#             "longitude": -9.1330428
#         },
#         "id": "30624065",
#         "price": 360000,
#         "size": 132,
#         "url": "https://www.idealista.pt/en/imovel/30624065/"
#     },
#     "30624279": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30624279",
#         "price": 590000,
#         "size": 122,
#         "url": "https://www.idealista.pt/en/imovel/30624279/"
#     },
#     "30624325": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30624325",
#         "price": 685000,
#         "size": 132,
#         "url": "https://www.idealista.pt/en/imovel/30624325/"
#     },
#     "30624354": {
#         "address": "Baixa%2C%20Santa%20Maria%20Maior",
#         "id": "30624354",
#         "price": 550000,
#         "size": 140,
#         "url": "https://www.idealista.pt/en/imovel/30624354/"
#     },
#     "30624399": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30624399",
#         "price": 1990000,
#         "size": 381,
#         "url": "https://www.idealista.pt/en/imovel/30624399/"
#     },
#     "30624422": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30624422",
#         "price": 935000,
#         "size": 220,
#         "url": "https://www.idealista.pt/en/imovel/30624422/"
#     },
#     "30624425": {
#         "address": "Campo%20de%20Ourique%2C%20Lisboa",
#         "id": "30624425",
#         "price": 650000,
#         "size": 126,
#         "url": "https://www.idealista.pt/en/imovel/30624425/"
#     },
#     "30624427": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30624427",
#         "price": 595000,
#         "size": 143,
#         "url": "https://www.idealista.pt/en/imovel/30624427/"
#     },
#     "30624429": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30624429",
#         "price": 655000,
#         "size": 103,
#         "url": "https://www.idealista.pt/en/imovel/30624429/"
#     },
#     "30624431": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30624431",
#         "price": 745000,
#         "size": 102,
#         "url": "https://www.idealista.pt/en/imovel/30624431/"
#     },
#     "30624457": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30624457",
#         "price": 780000,
#         "size": 108,
#         "url": "https://www.idealista.pt/en/imovel/30624457/"
#     },
#     "30624458": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30624458",
#         "price": 760000,
#         "size": 101,
#         "url": "https://www.idealista.pt/en/imovel/30624458/"
#     },
#     "30624460": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30624460",
#         "price": 730000,
#         "size": 106,
#         "url": "https://www.idealista.pt/en/imovel/30624460/"
#     },
#     "30624463": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30624463",
#         "price": 735000,
#         "size": 105,
#         "url": "https://www.idealista.pt/en/imovel/30624463/"
#     },
#     "30624465": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30624465",
#         "price": 760000,
#         "size": 104,
#         "url": "https://www.idealista.pt/en/imovel/30624465/"
#     },
#     "30624466": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30624466",
#         "price": 775000,
#         "size": 106,
#         "url": "https://www.idealista.pt/en/imovel/30624466/"
#     },
#     "30624571": {
#         "address": "S%C3%A3o%20Sebasti%C3%A3o%20da%20Pedreira%2C%20Avenidas%20Novas",
#         "id": "30624571",
#         "price": 1090000,
#         "size": 247,
#         "url": "https://www.idealista.pt/en/imovel/30624571/"
#     },
#     "30624618": {
#         "address": "Quinta%20dos%20Alcoutins%2C%20Lumiar",
#         "id": "30624618",
#         "price": 1500000,
#         "size": 440,
#         "url": "https://www.idealista.pt/en/imovel/30624618/"
#     },
#     "30624620": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30624620",
#         "price": 1240000,
#         "size": 170,
#         "url": "https://www.idealista.pt/en/imovel/30624620/"
#     },
#     "30624639": {
#         "address": "Prazeres%2C%20Estrela",
#         "id": "30624639",
#         "price": 525000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30624639/"
#     },
#     "30624665": {
#         "address": "Estef%C3%A2nia%20-%20Bairro%20das%20Ilhas%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30624665",
#         "price": 497000,
#         "size": 114,
#         "url": "https://www.idealista.pt/en/imovel/30624665/"
#     },
#     "30624865": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30624865",
#         "price": 430000,
#         "size": 165,
#         "url": "https://www.idealista.pt/en/imovel/30624865/"
#     },
#     "30624867": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30624867",
#         "price": 360000,
#         "size": 165,
#         "url": "https://www.idealista.pt/en/imovel/30624867/"
#     },
#     "30624868": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30624868",
#         "price": 450000,
#         "size": 227,
#         "url": "https://www.idealista.pt/en/imovel/30624868/"
#     },
#     "30624871": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30624871",
#         "price": 590000,
#         "size": 258,
#         "url": "https://www.idealista.pt/en/imovel/30624871/"
#     }
# }
