# %%
import requests
from bs4 import BeautifulSoup
import textwrap
from datetime import datetime
import json
import urllib

# %%
with open("scrap.json") as json_file:
    scrap_json = json.load(json_file)
print('Loaded scrap json:\n\tUID: {}'.format(scrap_json['uid']))
# Out:
# Loaded scrap json:
# 	UID: 55c5fd9dadafwmbu5lzwmd2vx5d2agxggm894hqnht8

# %% [markdown]
# ## Ad scrapping

# %%
def json_to_cookie(cookie_json):
    return '; '.join(['{}={}'.format(k,v) for k, v in cookie_json.items()])
#print(cookie_str, new_cookie_str)

#print compare
def compare_print(a, b):
    print('{:>55} | {:<55}'.format('A','B'))
    print('-'*113)
    for i in range(len(a)):
        a_el = ''
        b_el = ''
        if(len(a) > i):
            a_el = a[i]
        if(len(b) > i):
            b_el = b[i]
        print('{:<55} | {:<55}'.format(a_el,b_el))

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'cookie': json_to_cookie(scrap_json['cookie'])
}

# %%
articles = []

host = 'https://www.idealista.pt'
path = 'en/comprar-casas'
region = 'lisboa'
params = ['com-tamanho-min_100','publicado_ultimas-48-horas']
url = '/' + '/'.join([path,region,','.join(params)])

i = 0
while url:
    i += 1
    url = host + url
    print('{}) Request URL: {}'.format(i, url))
    
    req = requests.get(url, headers)
    if(req.status_code != 200):
        print('{}) HTTP Code {}\n\tBody: {}'.format(i, req.status_code,req.text))
        break
    
    soup = BeautifulSoup(req.content, 'html.parser')
    
    articles += soup.find_all('article')
    
    print('\tArticles/Ads found: {}'.format(len(articles)))
    pagination = soup.find('div', 'pagination')

    next_page_tag = pagination.find('a', 'icon-arrow-right-after')
    url = next_page_tag.get('href') if next_page_tag else None
# Out:
# 1) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas
# 	Articles/Ads found: 32
# 2) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-2
# 	Articles/Ads found: 64
# 3) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-3
# 	Articles/Ads found: 96
# 4) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-4
# 	Articles/Ads found: 128
# 5) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-5
# 	Articles/Ads found: 160
# 6) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-6
# 	Articles/Ads found: 180

# %%
#print(articles[0].prettify())

items = []
for ad in articles:
    # .info-data-price
    if('adv' in ad.attrs['class']):
        continue
    item_price = ad.find('span', class_='item-price')
    item_detail = ad.find_all('span', class_='item-detail')
    item_link = ad.find('a', class_='item-link')
    item_title = item_link.get('title')
    item_id = ad.get('data-adid')
    
    price = int(item_price.get_text()[:-1].replace(',',''))
    address = urllib.parse.quote(item_title[item_title.find(' in ')+4:]) if item_title.find(' in ') != - 1 else item_title
    size = int(item_detail[1].get_text()[:-3].replace(',','')) if len(item_detail) > 1 else print('{} Failed to fetch area!'.format(item_id))
    item_url = '{}{}'.format(host,item_link.get('href'))

    items.append({
        'price': price,
        'address': address,
        'id': item_id,
        'size': size,
        'url': item_url
    })
    #print(json.dumps(items_dict[item_id], indent=4, sort_keys=True))
print('Ads parsed: {}'.format(len(items)))
# Out:
# Ads parsed: 169

# %%
time_format = '%d-%m-%Y_%H:%M:%S_scrap'
data_path = './data_scrap'

now = datetime.now()
s2 = now.strftime(time_format)

f = open(data_path + '/' + s2 + ".json","w")
f.write(json.dumps(items))
f.close()

# %% [markdown]
# ## Ad GeoLocation (scrapped from Idealista)

# %%
import urllib
# TODO go around the map taking the places
params_dict = dict(
    locationUri='lisboa',
    typology='1',
    operation='1',
    zoom='5',
    northEast='54.17960751741163,16.15620517730715',
    southWest='19.08984486221779,-34.46879482269287',
    uid=scrap_json['uid'],
    adfilter_pricemin='default',
    adfilter_price='700000',
    adfilter_area='100',
    adfilter_areamax='default',
    adfilter_published='default'
)
params_dict['solo-favoritos'] = 'false'
params = urllib.parse.urlencode(params_dict, doseq=True)

host = 'https://www.idealista.pt'
path = '/ajax/listingcontroller/listingmapajax.ajax'

new_url = '{}{}?{}'.format(host,path,params)


req = requests.get(new_url, headers)
print(req)
ajax_listing_json = req.json()
json_resp = ajax_listing_json['jsonResponse']

print(json_resp.keys(), len(json_resp['map']['items']))

print(len(json_resp['map']['items']), json_resp['listingTotalResults'])
for geo in json_resp['map']['items']:
    print(geo['adId'])
# Out:
# <Response [200]>
# dict_keys(['valueH1', 'description', 'total', 'result', 'errorMessage', 'searchFeaturesPhrase', 'searchPhrase', 'howmany', 'search', 'breadcrumbUrlValue', 'breadcrumbUrlAllMunicipalitiesLevel', 'mapSearchUrl', 'listingSearchUrl', 'rentListingSearchUrl', 'saleListingSearchUrlMobile', 'newDevelopmentUrlMobile', 'newDevelopmentUrl', 'saleListingSearchUrl', 'rentListingSearchUrlMobile', 'pagetarget', 'searchTotalsUrl', 'searchWithoutFilters', 'listingTotalResults', 'listingPriceByArea', 'map', 'existAlert']) 1300
# 1300 4.134
# 30574563
# 30474960
# 30454160
# 30500116
# 30442424
# 30441597
# 30255778
# 30513024
# 30601215
# 30544767
# 30593991
# 30448223
# 29928128
# 30189798
# 30105276
# 30190564
# 30190559
# 30430613
# 30247975
# 30519376
# 30188038
# 30300785
# 30212191
# 30212192
# 30509477
# 30212208
# 29663193
# 29125722
# 30531506
# 30324143
# 30483168
# 30307170
# 30307138
# 30497990
# 29733615
# 29953067
# 30195468
# 29760218
# 30279701
# 30171998
# 30171994
# 30172453
# 30172475
# 30171995
# 30171989
# 30184103
# 30177544
# 30411086
# 30578969
# 30579033
# 30323175
# 30271970
# 30508519
# 30545873
# 30548846
# 30548831
# 30548832
# 30548852
# 30548850
# 28722785
# 30566607
# 29839441
# 30336240
# 30524931
# 30515559
# 30272272
# 30236328
# 30450654
# 28913068
# 29130767
# 30531663
# 30360956
# 30360952
# 30346263
# 29743272
# 30215749
# 29805147
# 30262381
# 29712030
# 29754589
# 30195518
# 30321672
# 29365025
# 30374964
# 30540315
# 30208808
# 30592882
# 29969524
# 29490003
# 29991522
# 30356212
# 30206452
# 30141135
# 30093467
# 30320596
# 30421636
# 30466689
# 30495942
# 30500469
# 30606469
# 30339192
# 30570162
# 30514605
# 30357060
# 30606523
# 30557460
# 30502116
# 30588445
# 30081908
# 30613632
# 30092299
# 30221226
# 29898685
# 30579238
# 30399474
# 30399350
# 30426766
# 30426405
# 30210114
# 30309983
# 30524459
# 30617397
# 29824210
# 29862289
# 30603794
# 30472055
# 29153459
# 30505826
# 30565945
# 30491771
# 30072703
# 30505012
# 30535197
# 30552992
# 30552104
# 30500215
# 30605253
# 29759454
# 30522361
# 30473925
# 30524708
# 29329061
# 30421460
# 30238666
# 30372287
# 30539553
# 30574485
# 30594916
# 30210208
# 30622614
# 30266788
# 30403463
# 30356979
# 30091767
# 29887375
# 30580214
# 28861956
# 30518196
# 29815720
# 30366953
# 30588181
# 30067877
# 30081667
# 30456377
# 30571786
# 30062107
# 30458424
# 30623238
# 30367090
# 30175002
# 30456237
# 30569625
# 30539974
# 29999442
# 29999497
# 29943509
# 30409625
# 30282017
# 30302606
# 30587577
# 30159103
# 30454240
# 30393162
# 30391850
# 30391883
# 30391873
# 30526761
# 30560405
# 30396805
# 30396586
# 30478829
# 30341029
# 30505433
# 30629109
# 30613630
# 30629242
# 29221610
# 30567910
# 30272827
# 29374943
# 29973505
# 30292575
# 30454549
# 30505267
# 30504817
# 30106996
# 30285584
# 29819466
# 30505699
# 30252214
# 29625192
# 30519166
# 30594287
# 30603900
# 30509835
# 30574506
# 30433818
# 30627494
# 30627480
# 29369283
# 30402236
# 30624639
# 30132158
# 30529995
# 30201596
# 30631414
# 30628198
# 30199936
# 30400417
# 30454590
# 30619986
# 30296908
# 30303104
# 29384667
# 30412553
# 30412555
# 30470186
# 30560495
# 30632457
# 30089300
# 30521619
# 30336656
# 30307441
# 30312747
# 30542716
# 30443869
# 30437451
# 30566685
# 29162771
# 30589953
# 30515999
# 30339202
# 30601371
# 30624065
# 30601480
# 30617218
# 30631784
# 30526565
# 30634694
# 30479033
# 30529359
# 28612608
# 30355805
# 30458329
# 30513996
# 29532507
# 29479401
# 30172930
# 30412527
# 30526254
# 30579297
# 30629894
# 29841060
# 30589930
# 30315691
# 30603435
# 30449665
# 30555916
# 30635547
# 30617432
# 30307746
# 30393710
# 30632779
# 30276006
# 30570757
# 30635426
# 30523788
# 30471819
# 30563408
# 30516943
# 30575517
# 30142283
# 29881105
# 30525036
# 29054390
# 30617948
# 30617957
# 30589846
# 30634724
# 29952395
# 30041316
# 30590561
# 30637547
# 30637553
# 30468331
# 30165032
# 30338602
# 30625338
# 30336321
# 30579198
# 30634973
# 30092025
# 30359927
# 29927185
# 30374701
# 30183212
# 30588107
# 30396787
# 30364476
# 29803285
# 29803246
# 30386018
# 30419328
# 30419342
# 30369632
# 30218593
# 30581620
# 30502699
# 30546123
# 29913697
# 30636348
# 30636263
# 30439828
# 30199522
# 30549321
# 30518921
# 30232719
# 30456239
# 30579195
# 30629320
# 29489625
# 30387846
# 30427732
# 30578514
# 30559481
# 30561757
# 30560348
# 30555216
# 30561742
# 30631632
# 30302927
# 30302941
# 30302942
# 30466694
# 30243682
# 30163755
# 30484389
# 30287343
# 30505145
# 30505144
# 30497580
# 30564438
# 30467385
# 30596701
# 30573783
# 30291699
# 30416562
# 30470472
# 29902908
# 30630532
# 30253583
# 30200768
# 30592924
# 30187147
# 30577791
# 30618974
# 30631136
# 30376754
# 30599084
# 30612499
# 30394442
# 29957476
# 30593388
# 29957472
# 30411774
# 30582030
# 27944387
# 30489685
# 30590144
# 30579787
# 30604910
# 30603417
# 30214224
# 30582059
# 30581426
# 29023676
# 29959900
# 30286746
# 29057735
# 30302385
# 30619104
# 30169791
# 28609479
# 30592872
# 30460840
# 29650920
# 29982673
# 30352803
# 30287423
# 30533407
# 30268784
# 30608894
# 30533410
# 30551775
# 30378560
# 30435919
# 30258280
# 30066402
# 30447102
# 30401811
# 30516050
# 30533416
# 30162667
# 29507940
# 30507236
# 29538385
# 30288184
# 29787670
# 30323453
# 29131396
# 29595298
# 30303912
# 30596934
# 30430601
# 30234625
# 30557754
# 30563385
# 30412939
# 30049746
# 30074763
# 30577271
# 30560885
# 30003813
# 30596385
# 30098784
# 28150004
# 30522713
# 29268953
# 29041599
# 30157089
# 30635867
# 29976275
# 30515452
# 30267849
# 30623668
# 30460078
# 30615193
# 30325805
# 30217422
# 30310723
# 28561985
# 30468796
# 28879126
# 28196977
# 30624665
# 30397054
# 29614806
# 29659306
# 30567259
# 30574177
# 30469282
# 30348361
# 29997270
# 29125184
# 30567249
# 30300599
# 30618445
# 29873119
# 30567209
# 30592058
# 30047576
# 29756143
# 30554339
# 30013667
# 30493491
# 30206090
# 30633266
# 30311012
# 30593270
# 30430390
# 30430395
# 30430394
# 29466773
# 30475614
# 30267799
# 29643710
# 30232644
# 30529976
# 29382496
# 30604617
# 30370981
# 30633159
# 30524099
# 30164464
# 30164470
# 30460239
# 29886613
# 29116652
# 29880008
# 30173751
# 30469941
# 29886086
# 29886087
# 29852705
# 29886017
# 30379585
# 30301539
# 30091854
# 30072304
# 30247549
# 30562947
# 29601916
# 30587933
# 29802419
# 30400890
# 30531922
# 30513837
# 29979862
# 30432584
# 30594300
# 30119908
# 30119912
# 28528706
# 30627243
# 30300122
# 30438567
# 30177012
# 28800704
# 30300123
# 29883092
# 30537540
# 30119873
# 30579902
# 30317709
# 29886020
# 28523240
# 30555228
# 30626322
# 29886072
# 30016961
# 30429208
# 29334333
# 30026431
# 28976116
# 29855454
# 30414361
# 30268975
# 30236913
# 30212274
# 30428534
# 30561805
# 30110184
# 30471046
# 30208702
# 30560964
# 30241515
# 30307821
# 30209531
# 30569154
# 30559810
# 30505668
# 30472252
# 28922124
# 30461606
# 29052476
# 30210624
# 29874057
# 30276509
# 30266916
# 29491064
# 30629734
# 30130527
# 29752901
# 30531294
# 30441549
# 30532904
# 30164431
# 30164445
# 30164447
# 30164474
# 30164468
# 30164457
# 30164465
# 30368032
# 29025982
# 30164472
# 30164451
# 30164473
# 30294481
# 30269960
# 30016386
# 29508362
# 30441600
# 30172971
# 29074686
# 30532936
# 30533372
# 30222028
# 30336508
# 30257335
# 28913964
# 30551581
# 29895951
# 30091843
# 30091841
# 30159939
# 30091829
# 30421966
# 30617850
# 29617862
# 30390885
# 30564415
# 30522157
# 30521859
# 30201471
# 30366256
# 30484540
# 30479333
# 30530217
# 29886055
# 29886071
# 29886005
# 30529501
# 29886000
# 30152943
# 30430233
# 30065484
# 30171298
# 29868066
# 30501854
# 30546862
# 29932722
# 29320637
# 29320408
# 30199031
# 30493641
# 30517521
# 30083193
# 30541401
# 30222880
# 30133614
# 30310341
# 30226075
# 30570280
# 30598956
# 30460678
# 30530246
# 30363454
# 29936392
# 29060809
# 29060810
# 30511415
# 30208217
# 30278116
# 29008573
# 30472677
# 30588274
# 29552860
# 30630063
# 30462960
# 30478373
# 30277904
# 30138581
# 30278117
# 29568809
# 29011293
# 30517445
# 28794098
# 29842624
# 30243880
# 30415966
# 29876944
# 30269898
# 30618652
# 30213271
# 30270359
# 30100798
# 30067868
# 29718259
# 30439603
# 30390498
# 30570821
# 29539110
# 30063356
# 30456709
# 30241745
# 30460123
# 30296655
# 29509426
# 29706074
# 30460689
# 28789053
# 29509333
# 30589449
# 30243269
# 30201538
# 29994666
# 30192915
# 29470253
# 30257667
# 30227790
# 30358040
# 27868990
# 30545294
# 30414122
# 29397618
# 30478904
# 30021317
# 30299745
# 29842396
# 30545724
# 29462895
# 30462967
# 30117607
# 30265007
# 30249471
# 30528250
# 30117926
# 30561417
# 30184102
# 29725334
# 29790286
# 30595155
# 29937436
# 30298706
# 30606520
# 30311857
# 30344533
# 30214794
# 29904087
# 29920345
# 30166809
# 30214442
# 30574017
# 30016781
# 30509831
# 30427741
# 30001311
# 30247829
# 30427993
# 30524818
# 30573980
# 30183350
# 30476218
# 29541966
# 30081706
# 30441518
# 30518613
# 30289119
# 29730959
# 30354295
# 30354191
# 30254681
# 30224117
# 30518433
# 30026803
# 30092311
# 30220179
# 30416009
# 29829509
# 29763641
# 30324104
# 30190704
# 30091840
# 30290729
# 30337222
# 30026477
# 30026602
# 29534444
# 30414957
# 30531495
# 30236349
# 30219549
# 28993922
# 28517482
# 30560995
# 29976332
# 30537308
# 29761012
# 29823327
# 30632920
# 30452287
# 30401833
# 30587533
# 30385162
# 29069247
# 30566842
# 30566856
# 30464910
# 30490350
# 29727413
# 28239069
# 30588519
# 28921734
# 30074772
# 29893410
# 29474636
# 30569710
# 30621893
# 30292326
# 30444145
# 30126841
# 30570201
# 30444146
# 30294897
# 30453251
# 28733397
# 29978369
# 30393475
# 30535536
# 30459786
# 30491664
# 30238538
# 30566992
# 30502614
# 30623885
# 30624034
# 30303596
# 29059459
# 30519134
# 30235962
# 29109486
# 29045019
# 30497802
# 30320056
# 30385390
# 28877660
# 30215023
# 29893684
# 29535057
# 30321489
# 29886061
# 30283754
# 29053167
# 30398834
# 30398876
# 30071074
# 30138195
# 30352016
# 30022300
# 30450320
# 29496954
# 30234256
# 29560764
# 30496594
# 30580820
# 30024727
# 29480729
# 30614334
# 30398473
# 30156413
# 30075258
# 30033319
# 29059724
# 29737153
# 29376671
# 30435530
# 30031941
# 30340375
# 30308295
# 27095890
# 29782224
# 30569156
# 30175324
# 30328144
# 30573431
# 30599171
# 29873794
# 30191471
# 30295808
# 30557158
# 30630103
# 30331003
# 30427481
# 30577895
# 30557163
# 30493898
# 30636530
# 28884161
# 28884159
# 30162986
# 30440666
# 30610370
# 30548197
# 30326805
# 30463126
# 30530361
# 29686070
# 29379504
# 30317157
# 30599127
# 29379502
# 30570397
# 28289176
# 30622484
# 30592392
# 30534299
# 30544948
# 30544932
# 30570425
# 30564151
# 29562145
# 30251729
# 30484858
# 30151822
# 30567580
# 30245130
# 30401877
# 30509676
# 30387623
# 30387624
# 30387605
# 29008621
# 29710053
# 30387608
# 29333133
# 30057547
# 30433779
# 30554614
# 30314457
# 30573432
# 30301306
# 30211546
# 30622599
# 30187317
# 30187320
# 30552225
# 30610383
# 30453569
# 30534395
# 30133763
# 30133761
# 30416696
# 30425950
# 30496798
# 30557203
# 30449550
# 30473430
# 30342652
# 30409023
# 30000339
# 30427480
# 30220967
# 30220979
# 30230811
# 30540478
# 30230804
# 30483563
# 30342705
# 30530371
# 30437754
# 30564148
# 29562146
# 30525934
# 29451633
# 30305202
# 30111016
# 30317144
# 30517781
# 30295792
# 30570416
# 30330970
# 30610344
# 30628528
# 30483591
# 30596798
# 30488674
# 30191484
# 30359419
# 30401888
# 29813319
# 30523378
# 30548255
# 30610427
# 30618810
# 30396139
# 30616662
# 30559244
# 30578721
# 30576018
# 30629255
# 30613115
# 30612312
# 30632620
# 30562323
# 30586498
# 30452657
# 30602818
# 30636056
# 30573846
# 30559489
# 30414815
# 30314113
# 30606771
# 30596471
# 30411796
# 29979511
# 30179345
# 30580910
# 30081029
# 29868058
# 28929916
# 30620316
# 29991216
# 29985100
# 29985092
# 29985112
# 29991180
# 29991184
# 30536079
# 30445985
# 30364636
# 30458905
# 30608222
# 30527219
# 30281611
# 30593563
# 30549634
# 30593554
# 30312411
# 30535877
# 30436547
# 30593644
# 30536053
# 30005113
# 29551591
# 30264427
# 30458893
# 30500557
# 30536150
# 30500570
# 29654494
# 30397778
# 29654502
# 30576524
# 30527535
# 30500565
# 28989399
# 28998613
# 29006151
# 30375444
# 30469550
# 29654492
# 29926464
# 29654500
# 30549747
# 30500567
# 29654495
# 30426505
# 29991229
# 29985087
# 29991219
# 29985101
# 29991187
# 30412367
# 29985066
# 29985062
# 29985084
# 29991228
# 29985102
# 29991238
# 29991240
# 29985110
# 30275308
# 30625484
# 30558290
# 30470724
# 30541818
# 29991207
# 30229557
# 29991223
# 29985097
# 29991237
# 29985093
# 29991239
# 29991177
# 29991181
# 29991197
# 29991185
# 29074327
# 30507431
# 29985083
# 29991217
# 30108431
# 29991204
# 29991192
# 29895116
# 30324540
# 30315282
# 29985077
# 29985108
# 29991176
# 29985050
# 29991194
# 29985052
# 30639239
# 30353342
# 30604721
# 29312393
# 30334303
# 30409469
# 27879765
# 30608155
# 30436501
# 27880326
# 30334286
# 29818082
# 30634032
# 29054084
# 30159375
# 30611505
# 30634105
# 30254999
# 27880323
# 27880345
# 30334307
# 30334285
# 29742913
# 30334275
# 29743189
# 30334290
# 30474512
# 30521008
# 29633207
# 29805517
# 30394923
# 28882515
# 29711271
# 29451831
# 29805515
# 30058542
# 30593536
# 30620182
# 29900990
# 30105423
# 30394928
# 30181868
# 30061759
# 30317935
# 30383145
# 30240993
# 28371731
# 30049298
# 30375335
# 30084769
# 30512673
# 30470749
# 28981341
# 30341121
# 30298980
# 29930154
# 30553202
# 30634126
# 30334489
# 30312562
# 30500658
# 30549822
# 30509900
# 30302169
# 30341231
# 30498187
# 30498189
# 30302162
# 30315396
# 30261230
# 30581244
# 30357746
# 30509923
# 30558525
# 29926501
# 30581237
# 30581245
# 30275611
# 30636978
# 30536380
# 30412412
# 30512782
# 30302159
# 30507971
# 29791381
# 29960095
# 30075779
# 30397751
# 30245889
# 30590977
# 30128925
# 30604811
# 29610408
# 30436526
# 30426524
# 30634116
# 30458797
# 29886417
# 30124405
# 29967431
# 30535917
# 30254990
# 29987310
# 30275495
# 29830315
# 29279841
# 30498165
# 30235407
# 30362399
# 30137623
# 30620618
# 30480024
# 29103900
# 30346734
# 28797020
# 30591210
# 30634291
# 30576603
# 30287026
# 29484316
# 30541949
# 30536365
# 30334431
# 30438861
# 30636933
# 30527365
# 30458770
# 30608190
# 30465882
# 30271578
# 30541828
# 30590879
# 30622892
# 30137565
# 29375288
# 30218213
# 30218193
# 30576471
# 30611569
# 30105486
# 30324375
# 30553179
# 30235282
# 30608153
# 30620227
# 30334295
# 30334293
# 29107304
# 30441084
# 30521028
# 30420624
# 29771112
# 29895074
# 29534411
# 30477181
# 30187921
# 30049134
# 30255220
# 30581298
# 30354988
# 30441256
# 30495322
# 30049120
# 30064400
# 30180041
# 29852529
# 30084913
# 30168499
# 29882347
# 30364732
# 30482252
# 30466268
# 29957823
# 30357683
# 30593659
# 30498151
# 29027371
# 30558465
# 29777181
# 30622970
# 30296729
# 29027405
# 30364656
# 29027370
# 30120992
# 30565134
# 30546671
# 30636975
# 29027412
# 29027410
# 30255064
# 30425025
# 30553239
# 30527680
# 29387633

# %% [markdown]
# ## Join Ad and GeoLocation

# %%
items_dict = {}
for it in items:
    items_dict[it['id']] = it

geo_dict = {}
for geo in json_resp['map']['items']:
    geo_dict[geo['adId']] = geo
    
    if str(geo['adId']) in items_dict:
        items_dict[str(geo['adId'])]['geo'] = { 'latitude': geo['latitude'], 'longitude': geo['longitude'] }
        #print(items_dict[str(geo['adId'])])
print(json.dumps(items_dict, indent=4, sort_keys=True))
# Out:
# {
#     "29847229": {
#         "address": "Castelo%20-%20Mouraria%2C%20Santa%20Maria%20Maior",
#         "id": "29847229",
#         "price": 505000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/29847229/"
#     },
#     "30077386": {
#         "address": "Alto%20de%20S%C3%A3o%20Jo%C3%A3o%20-%20Alto%20do%20Varej%C3%A3o%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30077386",
#         "price": 760000,
#         "size": 179,
#         "url": "https://www.idealista.pt/en/imovel/30077386/"
#     },
#     "30229122": {
#         "address": "praceta%20Fernando%20Valle%2C%201%2C%20Santa%20Clara%2C%20Lisboa",
#         "id": "30229122",
#         "price": 620000,
#         "size": 250,
#         "url": "https://www.idealista.pt/en/imovel/30229122/"
#     },
#     "30360827": {
#         "address": "S%C3%A3o%20Sebasti%C3%A3o%20da%20Pedreira%2C%20Avenidas%20Novas",
#         "id": "30360827",
#         "price": 450000,
#         "size": 126,
#         "url": "https://www.idealista.pt/en/imovel/30360827/"
#     },
#     "30360840": {
#         "address": "S%C3%A3o%20Sebasti%C3%A3o%20da%20Pedreira%2C%20Avenidas%20Novas",
#         "id": "30360840",
#         "price": 750000,
#         "size": 126,
#         "url": "https://www.idealista.pt/en/imovel/30360840/"
#     },
#     "30588615": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30588615",
#         "price": 545000,
#         "size": 112,
#         "url": "https://www.idealista.pt/en/imovel/30588615/"
#     },
#     "30596545": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30596545",
#         "price": 790000,
#         "size": 195,
#         "url": "https://www.idealista.pt/en/imovel/30596545/"
#     },
#     "30620618": {
#         "address": "Olivais%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.774731,
#             "longitude": -9.1146489
#         },
#         "id": "30620618",
#         "price": 429000,
#         "size": 185,
#         "url": "https://www.idealista.pt/en/imovel/30620618/"
#     },
#     "30626965": {
#         "address": "Restelo%2C%20Bel%C3%A9m",
#         "id": "30626965",
#         "price": 797500,
#         "size": 160,
#         "url": "https://www.idealista.pt/en/imovel/30626965/"
#     },
#     "30632825": {
#         "address": "Telheiras%2C%20Lumiar",
#         "id": "30632825",
#         "price": 475000,
#         "size": 157,
#         "url": "https://www.idealista.pt/en/imovel/30632825/"
#     },
#     "30633159": {
#         "address": "rua%20Helena%20Vaz%20da%20Silva%2C%205%2C%20Alto%20do%20Lumiar%2C%20Lumiar",
#         "geo": {
#             "latitude": 38.7726199,
#             "longitude": -9.1535347
#         },
#         "id": "30633159",
#         "price": 475000,
#         "size": 136,
#         "url": "https://www.idealista.pt/en/imovel/30633159/"
#     },
#     "30633399": {
#         "address": "Ajuda%2C%20Lisboa",
#         "id": "30633399",
#         "price": 630000,
#         "size": 147,
#         "url": "https://www.idealista.pt/en/imovel/30633399/"
#     },
#     "30633481": {
#         "address": "S%C3%A3o%20Jo%C3%A3o%20de%20Brito%2C%20Alvalade",
#         "id": "30633481",
#         "price": 495000,
#         "size": 145,
#         "url": "https://www.idealista.pt/en/imovel/30633481/"
#     },
#     "30633505": {
#         "address": "rua%20Sebasti%C3%A3o%20Saraiva%20e%20Silva%2C%20Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30633505",
#         "price": 549900,
#         "size": 148,
#         "url": "https://www.idealista.pt/en/imovel/30633505/"
#     },
#     "30633634": {
#         "address": "Alto%20de%20S%C3%A3o%20Jo%C3%A3o%20-%20Alto%20do%20Varej%C3%A3o%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30633634",
#         "price": 289000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30633634/"
#     },
#     "30633668": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30633668",
#         "price": 967000,
#         "size": 156,
#         "url": "https://www.idealista.pt/en/imovel/30633668/"
#     },
#     "30633774": {
#         "address": "avenida%2024%20de%20Julho%2C%20NN%2C%20Cais%20do%20Sodr%C3%A9%20-%20S%C3%A3o%20Paulo%2C%20Miseric%C3%B3rdia",
#         "id": "30633774",
#         "price": 1138500,
#         "size": 154,
#         "url": "https://www.idealista.pt/en/imovel/30633774/"
#     },
#     "30633777": {
#         "address": "avenida%2024%20de%20Julho%2C%20NN%2C%20Cais%20do%20Sodr%C3%A9%20-%20S%C3%A3o%20Paulo%2C%20Miseric%C3%B3rdia",
#         "id": "30633777",
#         "price": 1650000,
#         "size": 153,
#         "url": "https://www.idealista.pt/en/imovel/30633777/"
#     },
#     "30633966": {
#         "address": "Telheiras%2C%20Lumiar",
#         "id": "30633966",
#         "price": 375000,
#         "size": 108,
#         "url": "https://www.idealista.pt/en/imovel/30633966/"
#     },
#     "30633995": {
#         "address": "rua%20Giovanni%20Antinori%2C%20NN%2C%20Ajuda%2C%20Lisboa",
#         "id": "30633995",
#         "price": 523950,
#         "size": 150,
#         "url": "https://www.idealista.pt/en/imovel/30633995/"
#     },
#     "30634007": {
#         "address": "T2 flat, Pra\u00e7a da Viscondessa dos Olivais, NN, Olivais, Lisboa",
#         "id": "30634007",
#         "price": 580000,
#         "size": 126,
#         "url": "https://www.idealista.pt/en/imovel/30634007/"
#     },
#     "30634032": {
#         "address": "rua%20Professor%20Jorge%20da%20Silva%20Horta%2C%20NN%2C%20Bairro%20de%20Santa%20Cruz%2C%20Benfica",
#         "geo": {
#             "latitude": 38.7456826,
#             "longitude": -9.2055703
#         },
#         "id": "30634032",
#         "price": 625000,
#         "size": 175,
#         "url": "https://www.idealista.pt/en/imovel/30634032/"
#     },
#     "30634105": {
#         "address": "rua%20Cais%20do%20Tojo%2C%20NN%2C%20Cais%20do%20Sodr%C3%A9%20-%20S%C3%A3o%20Paulo%2C%20Miseric%C3%B3rdia",
#         "geo": {
#             "latitude": 38.7081967,
#             "longitude": -9.151979
#         },
#         "id": "30634105",
#         "price": 650000,
#         "size": 4791,
#         "url": "https://www.idealista.pt/en/imovel/30634105/"
#     },
#     "30634116": {
#         "address": "Bairro%20Alto%20-%20Encarna%C3%A7%C3%A3o%2C%20Miseric%C3%B3rdia",
#         "geo": {
#             "latitude": 38.7137716,
#             "longitude": -9.1456288
#         },
#         "id": "30634116",
#         "price": 450000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30634116/"
#     },
#     "30634126": {
#         "address": "Campo%20Grande%2C%20Alvalade",
#         "geo": {
#             "latitude": 38.7582635,
#             "longitude": -9.1593029
#         },
#         "id": "30634126",
#         "price": 350000,
#         "size": 112,
#         "url": "https://www.idealista.pt/en/imovel/30634126/"
#     },
#     "30634136": {
#         "address": "passeio%20%C3%82ncoras%2C%20Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30634136",
#         "price": 799000,
#         "size": 302,
#         "url": "https://www.idealista.pt/en/imovel/30634136/"
#     },
#     "30634154": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30634154",
#         "price": 335000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30634154/"
#     },
#     "30634165": {
#         "address": "Ajuda%2C%20Lisboa",
#         "id": "30634165",
#         "price": 210000,
#         "size": 111,
#         "url": "https://www.idealista.pt/en/imovel/30634165/"
#     },
#     "30634206": {
#         "address": "Baixa%2C%20Santa%20Maria%20Maior",
#         "id": "30634206",
#         "price": 1057000,
#         "size": 151,
#         "url": "https://www.idealista.pt/en/imovel/30634206/"
#     },
#     "30634246": {
#         "address": "avenida%20do%20Brasil%2C%20S%C3%A3o%20Jo%C3%A3o%20de%20Brito%2C%20Alvalade",
#         "id": "30634246",
#         "price": 535000,
#         "size": 129,
#         "url": "https://www.idealista.pt/en/imovel/30634246/"
#     },
#     "30634277": {
#         "address": "rua%20Engenheiro%20Vieira%20da%20Silva%2C%20NN%2C%20Saldanha%20-%20Picoas%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30634277",
#         "price": 1200000,
#         "size": 288,
#         "url": "https://www.idealista.pt/en/imovel/30634277/"
#     },
#     "30634281": {
#         "address": "rua%20Virg%C3%ADlio%20Martinho%2C%20Carnide%2C%20Lisboa",
#         "id": "30634281",
#         "price": 395000,
#         "size": 149,
#         "url": "https://www.idealista.pt/en/imovel/30634281/"
#     },
#     "30634291": {
#         "address": "Carriche%2C%20Lumiar",
#         "geo": {
#             "latitude": 38.7809036,
#             "longitude": -9.1641103
#         },
#         "id": "30634291",
#         "price": 189000,
#         "size": 100490,
#         "url": "https://www.idealista.pt/en/imovel/30634291/"
#     },
#     "30634296": {
#         "address": "rua%20de%20S%C3%A3o%20Jo%C3%A3o%20da%20Pra%C3%A7a%2C%20NN%2C%20Alfama%20-%20S%C3%A9%2C%20Santa%20Maria%20Maior",
#         "id": "30634296",
#         "price": 375000,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30634296/"
#     },
#     "30634316": {
#         "address": "rua%20Francisco%20de%20Andrade%2C%20Alvalade%2C%20Alvalade",
#         "id": "30634316",
#         "price": 899900,
#         "size": 200,
#         "url": "https://www.idealista.pt/en/imovel/30634316/"
#     },
#     "30634330": {
#         "address": "Alfama%20-%20S%C3%A9%2C%20Santa%20Maria%20Maior",
#         "id": "30634330",
#         "price": 750000,
#         "size": 180,
#         "url": "https://www.idealista.pt/en/imovel/30634330/"
#     },
#     "30634345": {
#         "address": "estrada%20de%20Benfica%2C%20NN%2C%20Arneiros%20-%20Avenida%20Uruguai%20-%20Charquinho%2C%20Benfica",
#         "id": "30634345",
#         "price": 799000,
#         "size": 160,
#         "url": "https://www.idealista.pt/en/imovel/30634345/"
#     },
#     "30634367": {
#         "address": "rua%20Cidade%20de%20Bolama%2C%20NN%2C%20Olivais%2C%20Lisboa",
#         "id": "30634367",
#         "price": 499000,
#         "size": 144,
#         "url": "https://www.idealista.pt/en/imovel/30634367/"
#     },
#     "30634415": {
#         "address": "rua%20Cidade%20da%20Beira%2C%20NN%2C%20Olivais%2C%20Lisboa",
#         "id": "30634415",
#         "price": 362500,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30634415/"
#     },
#     "30634423": {
#         "address": "rua%20Professor%20Vieira%20de%20Almeida%2C%20NN%2C%20Telheiras%2C%20Lumiar",
#         "id": "30634423",
#         "price": 367900,
#         "size": 109,
#         "url": "https://www.idealista.pt/en/imovel/30634423/"
#     },
#     "30634472": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30634472",
#         "price": 540000,
#         "size": 137,
#         "url": "https://www.idealista.pt/en/imovel/30634472/"
#     },
#     "30634643": {
#         "address": "Bairro%20Azul%20-%20Parque%20Eduardo%20VII%2C%20Avenidas%20Novas",
#         "id": "30634643",
#         "price": 1200000,
#         "size": 248,
#         "url": "https://www.idealista.pt/en/imovel/30634643/"
#     },
#     "30634694": {
#         "address": "estrada%20de%20Chelas%2C%20Alto%20de%20S%C3%A3o%20Jo%C3%A3o%20-%20Alto%20do%20Varej%C3%A3o%2C%20Penha%20de%20Fran%C3%A7a",
#         "geo": {
#             "latitude": 38.7257165,
#             "longitude": -9.1173207
#         },
#         "id": "30634694",
#         "price": 289000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30634694/"
#     },
#     "30634717": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30634717",
#         "price": 559000,
#         "size": 148,
#         "url": "https://www.idealista.pt/en/imovel/30634717/"
#     },
#     "30634724": {
#         "address": "Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "geo": {
#             "latitude": 38.729797,
#             "longitude": -9.1289414
#         },
#         "id": "30634724",
#         "price": 549900,
#         "size": 143,
#         "url": "https://www.idealista.pt/en/imovel/30634724/"
#     },
#     "30634743": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30634743",
#         "price": 685000,
#         "size": 135,
#         "url": "https://www.idealista.pt/en/imovel/30634743/"
#     },
#     "30634973": {
#         "address": "Carriche%2C%20Lumiar",
#         "geo": {
#             "latitude": 38.7806835,
#             "longitude": -9.1667263
#         },
#         "id": "30634973",
#         "price": 280000,
#         "size": 120,
#         "url": "https://www.idealista.pt/en/imovel/30634973/"
#     },
#     "30635123": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30635123",
#         "price": 575000,
#         "size": 122,
#         "url": "https://www.idealista.pt/en/imovel/30635123/"
#     },
#     "30635277": {
#         "address": "Prazeres%2C%20Estrela",
#         "id": "30635277",
#         "price": 525000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30635277/"
#     },
#     "30635282": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30635282",
#         "price": 785000,
#         "size": 118,
#         "url": "https://www.idealista.pt/en/imovel/30635282/"
#     },
#     "30635425": {
#         "address": "alameda%20Dom%20Afonso%20Henriques%2C%20Alameda%20-%20Pra%C3%A7a%20do%20Chile%20-%20Almirante%20Reis%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30635425",
#         "price": 900000,
#         "size": 230,
#         "url": "https://www.idealista.pt/en/imovel/30635425/"
#     },
#     "30635426": {
#         "address": "Bairro%20Azul%20-%20Parque%20Eduardo%20VII%2C%20Avenidas%20Novas",
#         "geo": {
#             "latitude": 38.7292684,
#             "longitude": -9.1569071
#         },
#         "id": "30635426",
#         "price": 695000,
#         "size": 175,
#         "url": "https://www.idealista.pt/en/imovel/30635426/"
#     },
#     "30635487": {
#         "address": "Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30635487",
#         "price": 175000,
#         "size": 105,
#         "url": "https://www.idealista.pt/en/imovel/30635487/"
#     },
#     "30635511": {
#         "address": "rua%20Abranches%20Ferr%C3%A3o%2C%20S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30635511",
#         "price": 725000,
#         "size": 204,
#         "url": "https://www.idealista.pt/en/imovel/30635511/"
#     },
#     "30635547": {
#         "address": "Duplex, Av. Estados Unidos da Am\u00e9rica, Alvalade, Alvalade",
#         "geo": {
#             "latitude": 38.7499553,
#             "longitude": -9.1404712
#         },
#         "id": "30635547",
#         "price": 430000,
#         "size": 126,
#         "url": "https://www.idealista.pt/en/imovel/30635547/"
#     },
#     "30635640": {
#         "address": "Beato%2C%20Lisboa",
#         "id": "30635640",
#         "price": 399000,
#         "size": 131,
#         "url": "https://www.idealista.pt/en/imovel/30635640/"
#     },
#     "30635642": {
#         "address": "avenida%20Ant%C3%B3nio%20Augusto%20de%20Aguiar%2C%20140%2C%20Bairro%20Azul%20-%20Parque%20Eduardo%20VII%2C%20Avenidas%20Novas",
#         "id": "30635642",
#         "price": 1100000,
#         "size": 154,
#         "url": "https://www.idealista.pt/en/imovel/30635642/"
#     },
#     "30635661": {
#         "address": "Campo%20Grande%2C%20Alvalade",
#         "id": "30635661",
#         "price": 410000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30635661/"
#     },
#     "30635755": {
#         "address": "S%C3%A3o%20Mamede%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30635755",
#         "price": 890000,
#         "size": 185,
#         "url": "https://www.idealista.pt/en/imovel/30635755/"
#     },
#     "30635809": {
#         "address": "Bairro%20Alto%20-%20Encarna%C3%A7%C3%A3o%2C%20Miseric%C3%B3rdia",
#         "id": "30635809",
#         "price": 986000,
#         "size": 145,
#         "url": "https://www.idealista.pt/en/imovel/30635809/"
#     },
#     "30635813": {
#         "address": "Castelo%20-%20Mouraria%2C%20Santa%20Maria%20Maior",
#         "id": "30635813",
#         "price": 525000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30635813/"
#     },
#     "30635814": {
#         "address": "Anjos%2C%20Arroios",
#         "id": "30635814",
#         "price": 780000,
#         "size": 275,
#         "url": "https://www.idealista.pt/en/imovel/30635814/"
#     },
#     "30635867": {
#         "address": "Areeiro%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7405383,
#             "longitude": -9.1273637
#         },
#         "id": "30635867",
#         "price": 699000,
#         "size": 168,
#         "url": "https://www.idealista.pt/en/imovel/30635867/"
#     },
#     "30635879": {
#         "address": "Telheiras%2C%20Lumiar",
#         "id": "30635879",
#         "price": 485000,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30635879/"
#     },
#     "30635936": {
#         "address": "Alvalade%2C%20Alvalade",
#         "id": "30635936",
#         "price": 1050000,
#         "size": 152,
#         "url": "https://www.idealista.pt/en/imovel/30635936/"
#     },
#     "30635938": {
#         "address": "S%C3%A3o%20Jo%C3%A3o%20de%20Brito%2C%20Alvalade",
#         "id": "30635938",
#         "price": 1750000,
#         "size": 800,
#         "url": "https://www.idealista.pt/en/imovel/30635938/"
#     },
#     "30635991": {
#         "address": "Santa%20Clara%2C%20Lisboa",
#         "id": "30635991",
#         "price": 395000,
#         "size": 166,
#         "url": "https://www.idealista.pt/en/imovel/30635991/"
#     },
#     "30636011": {
#         "address": "Anjos%2C%20Arroios",
#         "id": "30636011",
#         "price": 570000,
#         "size": 196,
#         "url": "https://www.idealista.pt/en/imovel/30636011/"
#     },
#     "30636047": {
#         "address": "Anjos%2C%20Arroios",
#         "id": "30636047",
#         "price": 1600000,
#         "size": 252,
#         "url": "https://www.idealista.pt/en/imovel/30636047/"
#     },
#     "30636056": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7041674,
#             "longitude": -9.1844551
#         },
#         "id": "30636056",
#         "price": 580000,
#         "size": 138,
#         "url": "https://www.idealista.pt/en/imovel/30636056/"
#     },
#     "30636076": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30636076",
#         "price": 875000,
#         "size": 205,
#         "url": "https://www.idealista.pt/en/imovel/30636076/"
#     },
#     "30636107": {
#         "address": "Campo%20de%20Ourique%2C%20Lisboa",
#         "id": "30636107",
#         "price": 535000,
#         "size": 124,
#         "url": "https://www.idealista.pt/en/imovel/30636107/"
#     },
#     "30636263": {
#         "address": "S%C3%A3o%20Jo%C3%A3o%20de%20Brito%2C%20Alvalade",
#         "geo": {
#             "latitude": 38.754632,
#             "longitude": -9.1322352
#         },
#         "id": "30636263",
#         "price": 550000,
#         "size": 124,
#         "url": "https://www.idealista.pt/en/imovel/30636263/"
#     },
#     "30636309": {
#         "address": "rua%20Professor%20Sim%C3%B5es%20Raposo%2C%20Telheiras%2C%20Lumiar",
#         "id": "30636309",
#         "price": 595000,
#         "size": 158,
#         "url": "https://www.idealista.pt/en/imovel/30636309/"
#     },
#     "30636348": {
#         "address": "rua%20Francisco%20Franco%2C%206%2C%20S%C3%A3o%20Jo%C3%A3o%20de%20Brito%2C%20Alvalade",
#         "geo": {
#             "latitude": 38.7556241,
#             "longitude": -9.1313812
#         },
#         "id": "30636348",
#         "price": 550000,
#         "size": 124,
#         "url": "https://www.idealista.pt/en/imovel/30636348/"
#     },
#     "30636429": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30636429",
#         "price": 495000,
#         "size": 117,
#         "url": "https://www.idealista.pt/en/imovel/30636429/"
#     },
#     "30636521": {
#         "address": "rua%20Azedo%20Gneco%2C%20Campo%20de%20Ourique%2C%20Lisboa",
#         "id": "30636521",
#         "price": 890000,
#         "size": 127,
#         "url": "https://www.idealista.pt/en/imovel/30636521/"
#     },
#     "30636522": {
#         "address": "Santa%20Catarina%2C%20Miseric%C3%B3rdia",
#         "id": "30636522",
#         "price": 500000,
#         "size": 119,
#         "url": "https://www.idealista.pt/en/imovel/30636522/"
#     },
#     "30636530": {
#         "address": "avenida%20Conselheiro%20Barjona%20de%20Freitas%2C%20S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.747116,
#             "longitude": -9.1842346
#         },
#         "id": "30636530",
#         "price": 280000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30636530/"
#     },
#     "30636826": {
#         "address": "Alfama%20-%20S%C3%A9%2C%20Santa%20Maria%20Maior",
#         "id": "30636826",
#         "price": 750000,
#         "size": 120,
#         "url": "https://www.idealista.pt/en/imovel/30636826/"
#     },
#     "30636908": {
#         "address": "rua%20Sargento%20Armando%20Monteiro%20Ferreira%2C%20NN%2C%20Olivais%2C%20Lisboa",
#         "id": "30636908",
#         "price": 250000,
#         "size": 126,
#         "url": "https://www.idealista.pt/en/imovel/30636908/"
#     },
#     "30636933": {
#         "address": "T3 flat, Cal\u00e7ada Moinho de Vento, NN, Pena, Arroios",
#         "geo": {
#             "latitude": 38.720302848772796,
#             "longitude": -9.140942670279365
#         },
#         "id": "30636933",
#         "price": 632500,
#         "size": 120,
#         "url": "https://www.idealista.pt/en/imovel/30636933/"
#     },
#     "30636934": {
#         "address": "rua%20Gon%C3%A7alves%20Zarco%2C%20NN%2C%20Bel%C3%A9m%2C%20Bel%C3%A9m",
#         "id": "30636934",
#         "price": 797500,
#         "size": 160,
#         "url": "https://www.idealista.pt/en/imovel/30636934/"
#     },
#     "30636975": {
#         "address": "rua%20Jos%C3%A9%20Bateira%2C%20Beato%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.731951,
#             "longitude": -9.1111356
#         },
#         "id": "30636975",
#         "price": 530000,
#         "size": 170,
#         "url": "https://www.idealista.pt/en/imovel/30636975/"
#     },
#     "30636978": {
#         "address": "beco%20Bica%20do%20Sapato%2C%20NN%2C%20S%C3%A3o%20Vicente%20de%20Fora%2C%20S%C3%A3o%20Vicente",
#         "geo": {
#             "latitude": 38.7169077,
#             "longitude": -9.1211538
#         },
#         "id": "30636978",
#         "price": 510000,
#         "size": 107,
#         "url": "https://www.idealista.pt/en/imovel/30636978/"
#     },
#     "30637332": {
#         "address": "largo%20Gra%C3%A7a%2C%20Gra%C3%A7a%2C%20S%C3%A3o%20Vicente",
#         "id": "30637332",
#         "price": 875000,
#         "size": 167,
#         "url": "https://www.idealista.pt/en/imovel/30637332/"
#     },
#     "30637438": {
#         "address": "rua%20Gil%20Vicente%2C%2060%2C%20Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30637438",
#         "price": 650000,
#         "size": 140,
#         "url": "https://www.idealista.pt/en/imovel/30637438/"
#     },
#     "30637450": {
#         "address": "Castelo%20-%20Mouraria%2C%20Santa%20Maria%20Maior",
#         "id": "30637450",
#         "price": 525000,
#         "size": 111,
#         "url": "https://www.idealista.pt/en/imovel/30637450/"
#     },
#     "30637500": {
#         "address": "rua%20General%20Farinha%20Beir%C3%A3o%2C%20Estef%C3%A2nia%20-%20Bairro%20das%20Ilhas%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30637500",
#         "price": 415000,
#         "size": 102,
#         "url": "https://www.idealista.pt/en/imovel/30637500/"
#     },
#     "30637547": {
#         "address": "avenida%20nuno%20kruz%20de%20abecassis%2C%20Santa%20Clara%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7808144,
#             "longitude": -9.153253
#         },
#         "id": "30637547",
#         "price": 530000,
#         "size": 179,
#         "url": "https://www.idealista.pt/en/imovel/30637547/"
#     },
#     "30637553": {
#         "address": "rua%20Jorge%20%C3%81lvares%2C%20Restelo%2C%20Bel%C3%A9m",
#         "geo": {
#             "latitude": 38.7077268,
#             "longitude": -9.2076215
#         },
#         "id": "30637553",
#         "price": 400000,
#         "size": 105,
#         "url": "https://www.idealista.pt/en/imovel/30637553/"
#     },
#     "30637613": {
#         "address": "Estef%C3%A2nia%20-%20Bairro%20das%20Ilhas%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30637613",
#         "price": 550000,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30637613/"
#     },
#     "30637620": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30637620",
#         "price": 437000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30637620/"
#     },
#     "30637645": {
#         "address": "Merc%C3%AAs%2C%20Miseric%C3%B3rdia",
#         "id": "30637645",
#         "price": 530000,
#         "size": 105,
#         "url": "https://www.idealista.pt/en/imovel/30637645/"
#     },
#     "30637658": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30637658",
#         "price": 1190000,
#         "size": 155,
#         "url": "https://www.idealista.pt/en/imovel/30637658/"
#     },
#     "30637660": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30637660",
#         "price": 1150000,
#         "size": 145,
#         "url": "https://www.idealista.pt/en/imovel/30637660/"
#     },
#     "30637661": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30637661",
#         "price": 1350000,
#         "size": 166,
#         "url": "https://www.idealista.pt/en/imovel/30637661/"
#     },
#     "30637662": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30637662",
#         "price": 1530000,
#         "size": 214,
#         "url": "https://www.idealista.pt/en/imovel/30637662/"
#     },
#     "30637664": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30637664",
#         "price": 1510000,
#         "size": 214,
#         "url": "https://www.idealista.pt/en/imovel/30637664/"
#     },
#     "30637665": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30637665",
#         "price": 1490000,
#         "size": 214,
#         "url": "https://www.idealista.pt/en/imovel/30637665/"
#     },
#     "30637667": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30637667",
#         "price": 1220000,
#         "size": 171,
#         "url": "https://www.idealista.pt/en/imovel/30637667/"
#     },
#     "30637668": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30637668",
#         "price": 1240000,
#         "size": 171,
#         "url": "https://www.idealista.pt/en/imovel/30637668/"
#     },
#     "30637670": {
#         "address": "Entrecampos%2C%20Avenidas%20Novas",
#         "id": "30637670",
#         "price": 875000,
#         "size": 205,
#         "url": "https://www.idealista.pt/en/imovel/30637670/"
#     },
#     "30637734": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30637734",
#         "price": 695000,
#         "size": 120,
#         "url": "https://www.idealista.pt/en/imovel/30637734/"
#     },
#     "30637759": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30637759",
#         "price": 2500000,
#         "size": 251,
#         "url": "https://www.idealista.pt/en/imovel/30637759/"
#     },
#     "30637765": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30637765",
#         "price": 925000,
#         "size": 133,
#         "url": "https://www.idealista.pt/en/imovel/30637765/"
#     },
#     "30637766": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30637766",
#         "price": 1050000,
#         "size": 172,
#         "url": "https://www.idealista.pt/en/imovel/30637766/"
#     },
#     "30637781": {
#         "address": "Alto%20do%20Lumiar%2C%20Lumiar",
#         "id": "30637781",
#         "price": 495000,
#         "size": 150,
#         "url": "https://www.idealista.pt/en/imovel/30637781/"
#     },
#     "30637955": {
#         "address": "Prazeres%2C%20Estrela",
#         "id": "30637955",
#         "price": 525000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30637955/"
#     },
#     "30637962": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30637962",
#         "price": 3750000,
#         "size": 319,
#         "url": "https://www.idealista.pt/en/imovel/30637962/"
#     },
#     "30638046": {
#         "address": "Carnide%2C%20Lisboa",
#         "id": "30638046",
#         "price": 740000,
#         "size": 240,
#         "url": "https://www.idealista.pt/en/imovel/30638046/"
#     },
#     "30638131": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30638131",
#         "price": 1640000,
#         "size": 297,
#         "url": "https://www.idealista.pt/en/imovel/30638131/"
#     },
#     "30638182": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30638182",
#         "price": 1100000,
#         "size": 336,
#         "url": "https://www.idealista.pt/en/imovel/30638182/"
#     },
#     "30638241": {
#         "address": "rua%20S%C3%A3o%20Juli%C3%A3o%2C%20Baixa%2C%20Santa%20Maria%20Maior",
#         "id": "30638241",
#         "price": 750000,
#         "size": 102,
#         "url": "https://www.idealista.pt/en/imovel/30638241/"
#     },
#     "30638259": {
#         "address": "Restelo%2C%20Bel%C3%A9m",
#         "id": "30638259",
#         "price": 1175000,
#         "size": 278,
#         "url": "https://www.idealista.pt/en/imovel/30638259/"
#     },
#     "30638275": {
#         "address": "S%C3%A3o%20Sebasti%C3%A3o%20da%20Pedreira%2C%20Avenidas%20Novas",
#         "id": "30638275",
#         "price": 565000,
#         "size": 102,
#         "url": "https://www.idealista.pt/en/imovel/30638275/"
#     },
#     "30638354": {
#         "address": "avenida%20de%20Alvalade%2C%202%2C%20S%C3%A3o%20Jo%C3%A3o%20de%20Brito%2C%20Alvalade",
#         "id": "30638354",
#         "price": 698000,
#         "size": 134,
#         "url": "https://www.idealista.pt/en/imovel/30638354/"
#     },
#     "30638462": {
#         "address": "rua%20De%20Dona%20Estef%C3%A2nia%2C%203%2C%20Pena%2C%20Arroios",
#         "id": "30638462",
#         "price": 390000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30638462/"
#     },
#     "30638519": {
#         "address": "rua%20Marqu%C3%AAs%20de%20Olh%C3%A3o%2C%20Beato%2C%20Lisboa",
#         "id": "30638519",
#         "price": 530000,
#         "size": 170,
#         "url": "https://www.idealista.pt/en/imovel/30638519/"
#     },
#     "30638539": {
#         "address": "rua%20Professor%20Reinaldo%20dos%20Santos%2C%20S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30638539",
#         "price": 330000,
#         "size": 144,
#         "url": "https://www.idealista.pt/en/imovel/30638539/"
#     },
#     "30638578": {
#         "address": "Santa%20Catarina%2C%20Miseric%C3%B3rdia",
#         "id": "30638578",
#         "price": 600000,
#         "size": 170,
#         "url": "https://www.idealista.pt/en/imovel/30638578/"
#     },
#     "30638589": {
#         "address": "rua%20do%20Bom%20Pastor%2C%20Fonte%20Nova%20-%20Monsanto%2C%20Benfica",
#         "id": "30638589",
#         "price": 510000,
#         "size": 134,
#         "url": "https://www.idealista.pt/en/imovel/30638589/"
#     },
#     "30638591": {
#         "address": "Bairro%20da%20Cal%C3%A7ada%20dos%20Mestres%20-%20Bairro%20da%20Liberdade%2C%20Campolide",
#         "id": "30638591",
#         "price": 480000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30638591/"
#     },
#     "30638674": {
#         "address": "Bairro%20Azul%20-%20Parque%20Eduardo%20VII%2C%20Avenidas%20Novas",
#         "id": "30638674",
#         "price": 850000,
#         "size": 183,
#         "url": "https://www.idealista.pt/en/imovel/30638674/"
#     },
#     "30638683": {
#         "address": "Bairro%20Alto%20-%20Encarna%C3%A7%C3%A3o%2C%20Miseric%C3%B3rdia",
#         "id": "30638683",
#         "price": 1500000,
#         "size": 215,
#         "url": "https://www.idealista.pt/en/imovel/30638683/"
#     },
#     "30638696": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30638696",
#         "price": 790000,
#         "size": 195,
#         "url": "https://www.idealista.pt/en/imovel/30638696/"
#     },
#     "30638750": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30638750",
#         "price": 875000,
#         "size": 206,
#         "url": "https://www.idealista.pt/en/imovel/30638750/"
#     },
#     "30638784": {
#         "address": "rua%20Jorge%20%C3%81lvares%2C%20Restelo%2C%20Bel%C3%A9m",
#         "id": "30638784",
#         "price": 400000,
#         "size": 115,
#         "url": "https://www.idealista.pt/en/imovel/30638784/"
#     },
#     "30638811": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30638811",
#         "price": 640000,
#         "size": 150,
#         "url": "https://www.idealista.pt/en/imovel/30638811/"
#     },
#     "30638837": {
#         "address": "avenida%20Jo%C3%A3o%20Cris%C3%B3stomo%2C%20Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30638837",
#         "price": 1300000,
#         "size": 250,
#         "url": "https://www.idealista.pt/en/imovel/30638837/"
#     },
#     "30639239": {
#         "address": "rua%20Carrilho%20Videira%2C%20Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "geo": {
#             "latitude": 38.7303738,
#             "longitude": -9.1294376
#         },
#         "id": "30639239",
#         "price": 549900,
#         "size": 148,
#         "url": "https://www.idealista.pt/en/imovel/30639239/"
#     },
#     "30639245": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30639245",
#         "price": 1400000,
#         "size": 179,
#         "url": "https://www.idealista.pt/en/imovel/30639245/"
#     },
#     "30639258": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30639258",
#         "price": 445000,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30639258/"
#     },
#     "30639268": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30639268",
#         "price": 1150000,
#         "size": 215,
#         "url": "https://www.idealista.pt/en/imovel/30639268/"
#     },
#     "30639293": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30639293",
#         "price": 579000,
#         "size": 181,
#         "url": "https://www.idealista.pt/en/imovel/30639293/"
#     },
#     "30639308": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30639308",
#         "price": 530000,
#         "size": 176,
#         "url": "https://www.idealista.pt/en/imovel/30639308/"
#     },
#     "30639318": {
#         "address": "S%C3%A3o%20Sebasti%C3%A3o%20da%20Pedreira%2C%20Avenidas%20Novas",
#         "id": "30639318",
#         "price": 830000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30639318/"
#     },
#     "30639327": {
#         "address": "Bairro%20Azul%20-%20Parque%20Eduardo%20VII%2C%20Avenidas%20Novas",
#         "id": "30639327",
#         "price": 715000,
#         "size": 138,
#         "url": "https://www.idealista.pt/en/imovel/30639327/"
#     },
#     "30639494": {
#         "address": "Prazeres%2C%20Estrela",
#         "id": "30639494",
#         "price": 525000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30639494/"
#     },
#     "30639545": {
#         "address": "avenida%20P%C3%A1dua%2C%20NN%2C%20Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30639545",
#         "price": 595000,
#         "size": 125,
#         "url": "https://www.idealista.pt/en/imovel/30639545/"
#     },
#     "30639547": {
#         "address": "rua%20Bar%C3%A3o%20de%20Sabrosa%2C%20NN%2C%20Bairro%20dos%20Actores%20-%20Bar%C3%A3o%20Sabrosa%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30639547",
#         "price": 195000,
#         "size": 116,
#         "url": "https://www.idealista.pt/en/imovel/30639547/"
#     },
#     "30639556": {
#         "address": "Santa%20Engr%C3%A1cia%2C%20S%C3%A3o%20Vicente",
#         "id": "30639556",
#         "price": 385000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30639556/"
#     },
#     "30639579": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30639579",
#         "price": 1640000,
#         "size": 298,
#         "url": "https://www.idealista.pt/en/imovel/30639579/"
#     },
#     "30639658": {
#         "address": "avenida%20Jo%C3%A3o%20Cris%C3%B3stomo%2C%20NN%2C%20Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30639658",
#         "price": 1300000,
#         "size": 228,
#         "url": "https://www.idealista.pt/en/imovel/30639658/"
#     },
#     "30639675": {
#         "address": "largo%20Carlos%20Selvagem%2C%20S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30639675",
#         "price": 679000,
#         "size": 123,
#         "url": "https://www.idealista.pt/en/imovel/30639675/"
#     },
#     "30639988": {
#         "address": "T3 flat, Av. afonso III, Alto de S\u00e3o Jo\u00e3o - Alto do Varej\u00e3o, Penha de Fran\u00e7a",
#         "id": "30639988",
#         "price": 279000,
#         "size": 120,
#         "url": "https://www.idealista.pt/en/imovel/30639988/"
#     },
#     "30639994": {
#         "address": "Anjos%2C%20Arroios",
#         "id": "30639994",
#         "price": 470000,
#         "size": 102,
#         "url": "https://www.idealista.pt/en/imovel/30639994/"
#     },
#     "30640038": {
#         "address": "rua%20Francisco%20de%20Andrade%2C%20Alvalade%2C%20Alvalade",
#         "id": "30640038",
#         "price": 899900,
#         "size": 200,
#         "url": "https://www.idealista.pt/en/imovel/30640038/"
#     },
#     "30640081": {
#         "address": "T3 flat, Av. Afonso III, Alto de S\u00e3o Jo\u00e3o - Alto do Varej\u00e3o, Penha de Fran\u00e7a",
#         "id": "30640081",
#         "price": 349000,
#         "size": 140,
#         "url": "https://www.idealista.pt/en/imovel/30640081/"
#     },
#     "30640125": {
#         "address": "S%C3%A3o%20Vicente%20de%20Fora%2C%20S%C3%A3o%20Vicente",
#         "id": "30640125",
#         "price": 695000,
#         "size": 120,
#         "url": "https://www.idealista.pt/en/imovel/30640125/"
#     },
#     "30640134": {
#         "address": "Campo%20de%20Ourique%2C%20Lisboa",
#         "id": "30640134",
#         "price": 220000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30640134/"
#     },
#     "30640140": {
#         "address": "Pena%2C%20Arroios",
#         "id": "30640140",
#         "price": 420000,
#         "size": 124,
#         "url": "https://www.idealista.pt/en/imovel/30640140/"
#     },
#     "30640141": {
#         "address": "Pena%2C%20Arroios",
#         "id": "30640141",
#         "price": 295000,
#         "size": 117,
#         "url": "https://www.idealista.pt/en/imovel/30640141/"
#     },
#     "30640186": {
#         "address": "Alvalade%2C%20Alvalade",
#         "id": "30640186",
#         "price": 765000,
#         "size": 150,
#         "url": "https://www.idealista.pt/en/imovel/30640186/"
#     },
#     "30640211": {
#         "address": "rua%20V%C3%ADtor%20Cordon%2C%20Chiado%2C%20Santa%20Maria%20Maior",
#         "id": "30640211",
#         "price": 1250000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30640211/"
#     },
#     "30640218": {
#         "address": "avenida%20Visconde%20de%20Valmor%2C%20Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30640218",
#         "price": 1300000,
#         "size": 244,
#         "url": "https://www.idealista.pt/en/imovel/30640218/"
#     },
#     "30640222": {
#         "address": "avenida%20Visconde%20de%20Valmor%2C%20Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30640222",
#         "price": 1300000,
#         "size": 290,
#         "url": "https://www.idealista.pt/en/imovel/30640222/"
#     },
#     "30640321": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30640321",
#         "price": 1220000,
#         "size": 196,
#         "url": "https://www.idealista.pt/en/imovel/30640321/"
#     },
#     "30640322": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30640322",
#         "price": 1350000,
#         "size": 191,
#         "url": "https://www.idealista.pt/en/imovel/30640322/"
#     },
#     "30640324": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30640324",
#         "price": 1150000,
#         "size": 166,
#         "url": "https://www.idealista.pt/en/imovel/30640324/"
#     },
#     "30640326": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30640326",
#         "price": 1490000,
#         "size": 246,
#         "url": "https://www.idealista.pt/en/imovel/30640326/"
#     },
#     "30640327": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30640327",
#         "price": 1530000,
#         "size": 246,
#         "url": "https://www.idealista.pt/en/imovel/30640327/"
#     },
#     "30640330": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30640330",
#         "price": 1190000,
#         "size": 177,
#         "url": "https://www.idealista.pt/en/imovel/30640330/"
#     },
#     "30640331": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30640331",
#         "price": 1510000,
#         "size": 246,
#         "url": "https://www.idealista.pt/en/imovel/30640331/"
#     },
#     "30640375": {
#         "address": "Carriche%2C%20Lumiar",
#         "id": "30640375",
#         "price": 282000,
#         "size": 104,
#         "url": "https://www.idealista.pt/en/imovel/30640375/"
#     },
#     "30640442": {
#         "address": "Merc%C3%AAs%2C%20Miseric%C3%B3rdia",
#         "id": "30640442",
#         "price": 624990,
#         "size": 109,
#         "url": "https://www.idealista.pt/en/imovel/30640442/"
#     },
#     "30640519": {
#         "address": "rua%20Engenheiro%20Ferry%20Borges%2C%206%2C%20Carnide%2C%20Lisboa",
#         "id": "30640519",
#         "price": 650000,
#         "size": 178,
#         "url": "https://www.idealista.pt/en/imovel/30640519/"
#     },
#     "30640536": {
#         "address": "rua%20Jos%C3%A9%20Maria%20Rodrigues%2C%20Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30640536",
#         "price": 395000,
#         "size": 118,
#         "url": "https://www.idealista.pt/en/imovel/30640536/"
#     },
#     "30640674": {
#         "address": "travessa%20de%20S.%20Bernardino%2C%20Pena%2C%20Arroios",
#         "id": "30640674",
#         "price": 880000,
#         "size": 200,
#         "url": "https://www.idealista.pt/en/imovel/30640674/"
#     }
# }

# %% [markdown]
# ## Real Estate Agency

# %%
agency = []
for it in items_dict.values():
    url = 'https://www.idealista.pt/pt/ajax/listingController/adContactInfoForListing.ajax?adId={}'.format(it['id'])
    req = requests.get(url, headers)
    agency.append(req)

# %%
[agent.json() for agent in agency]
# Out:
# [{'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': ' Casa ou moradia à venda  em Alvalade',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': '217920620',
#    'phoneRedirection': None,
#    'formattedContactPhone1': '915093625',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': '217920620',
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30640186,
#    'showProfessionalName': True,
#    'firstName': 'Pedro Oliveira',
#    'lastName': None,
#    'commercialName': 'KW Ábaco',
#    'referenceMessage': 'Ref.: 1196-2857',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'areeiro',
#    'commercialNamePhraseBlock': 'KW Ábaco',
#    'advertiserNameLink': '/pro/kwabaco/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/10/6d/62/kwabaco.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  na rua De Dona Estefânia, 3',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': '217920620',
#    'phoneRedirection': None,
#    'formattedContactPhone1': '925358869',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': '217920620',
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30638462,
#    'showProfessionalName': True,
#    'firstName': 'Francisco Freire Gameiro',
#    'lastName': None,
#    'commercialName': 'KW Ábaco',
#    'referenceMessage': 'Ref.: 1196-2827',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'areeiro',
#    'commercialNamePhraseBlock': 'KW Ábaco',
#    'advertiserNameLink': '/pro/kwabaco/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/10/6d/62/kwabaco.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T4 à venda  em Restelo',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215566243',
#    'formattedContactPhone1': '215566243',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30638259,
#    'showProfessionalName': True,
#    'firstName': 'CASHOUSE',
#    'lastName': None,
#    'commercialName': 'CASHOUSE',
#    'referenceMessage': 'Anúncio: 30638259',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'cascais e estoril',
#    'commercialNamePhraseBlock': 'CASHOUSE',
#    'advertiserNameLink': '/pro/cashouse/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/50/77/5f/cashouse.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T5 à venda  em Carnide',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215566243',
#    'formattedContactPhone1': '215566243',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30638046,
#    'showProfessionalName': True,
#    'firstName': 'CASHOUSE',
#    'lastName': None,
#    'commercialName': 'CASHOUSE',
#    'referenceMessage': 'Anúncio: 30638046',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'cascais e estoril',
#    'commercialNamePhraseBlock': 'CASHOUSE',
#    'advertiserNameLink': '/pro/cashouse/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/50/77/5f/cashouse.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  em Parque das Nações',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '210054118',
#    'formattedContactPhone1': '210054118',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30639293,
#    'showProfessionalName': True,
#    'firstName': 'century21 TIPY FAMILy',
#    'lastName': None,
#    'commercialName': 'Century21 Tipy Family',
#    'referenceMessage': 'Ref.: 0651-03278',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'Seixal',
#    'commercialNamePhraseBlock': 'Century21 Tipy Family',
#    'advertiserNameLink': '/pro/century21-tipy-family/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/d4/fb/d3/century21-tipy-family.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  na avenida António Augusto de Aguiar, 140',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': '217920620',
#    'phoneRedirection': None,
#    'formattedContactPhone1': '927917538',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': '217920620',
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30635642,
#    'showProfessionalName': True,
#    'firstName': 'Mateus Alçada',
#    'lastName': None,
#    'commercialName': 'KW Ábaco',
#    'referenceMessage': 'Ref.: 1196-2856',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'areeiro',
#    'commercialNamePhraseBlock': 'KW Ábaco',
#    'advertiserNameLink': '/pro/kwabaco/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/10/6d/62/kwabaco.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T4 à venda  em São Sebastião da Pedreira',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215553057',
#    'formattedContactPhone1': '215553057',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30360827,
#    'showProfessionalName': True,
#    'firstName': "Porta da Frente Christie's",
#    'lastName': None,
#    'commercialName': 'Porta da Frente',
#    'referenceMessage': 'Ref.: PF22337',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'cascais e estoril',
#    'commercialNamePhraseBlock': 'Porta da Frente',
#    'advertiserNameLink': '/pro/porta-da-frente-christies-international-real-estate/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/ed/c2/fc/porta-da-frente-christies-international-real-estate.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  em Prazeres',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': None,
#    'formattedContactPhone1': '928022726',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30637955,
#    'showProfessionalName': True,
#    'firstName': 'Geração XXI-Negócios Imobiliários',
#    'lastName': None,
#    'commercialName': 'Geração XXI-Negócios Imobiliários',
#    'referenceMessage': 'Ref.: GXXI 2058',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'Lisboa',
#    'commercialNamePhraseBlock': 'Geração XXI-Negócios Imobiliários',
#    'advertiserNameLink': '/pro/geracaoxxi/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/15/e1/46/geracaoxxi.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': True,
#    'isAdProfessional': False,
#    'agencyIsABank': None,
#    'shortDescription': 'Apartamento T3 à venda  em Telheiras',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 1,
#    'phone2': None,
#    'phoneRedirection': None,
#    'formattedContactPhone1': '914534883',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': 'apartamento',
#    'newDevelopmentDirectory': False,
#    'adId': 30632825,
#    'showProfessionalName': True,
#    'firstName': 'Margarida Geraldes',
#    'lastName': None,
#    'commercialName': '',
#    'referenceMessage': 'Anúncio: 30632825',
#    'isMicrosite': False,
#    'mustShowLogo': None,
#    'micrositeCityName': None,
#    'commercialNamePhraseBlock': None,
#    'advertiserNameLink': None,
#    'advertiserLogoUrl': None,
#    'isVirtualMicrosite': None,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  em Santa Clara',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215550195',
#    'formattedContactPhone1': '215550195',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30635991,
#    'showProfessionalName': True,
#    'firstName': 'MediPred - Mediação Imobiliária',
#    'lastName': None,
#    'commercialName': 'Medipred imobiliária',
#    'referenceMessage': 'Ref.: MJU9591R8',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'ramada e caneças',
#    'commercialNamePhraseBlock': 'Medipred imobiliária',
#    'advertiserNameLink': '/pro/medipred-imobiliaria/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/e6/ba/8a/medipred-imobiliaria.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  na rua São Julião',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215558127',
#    'formattedContactPhone1': '215558127',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30638241,
#    'showProfessionalName': True,
#    'firstName': 'Aria Imobiliária',
#    'lastName': None,
#    'commercialName': 'Aria Imobiliária',
#    'referenceMessage': 'Ref.: ARIAAP14.20',
#    'isMicrosite': True,
#    'mustShowLogo': False,
#    'micrositeCityName': 'carnaxide e queijas',
#    'commercialNamePhraseBlock': 'Aria Imobiliária',
#    'advertiserNameLink': '/pro/ariamedimob/',
#    'advertiserLogoUrl': None,
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  em Urb. rua Alexandre Ferreira, Carriche',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215558427',
#    'formattedContactPhone1': '215558427',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30640375,
#    'showProfessionalName': True,
#    'firstName': 'RoyalTeam Consultores',
#    'lastName': None,
#    'commercialName': 'RoyalTeam Consultores',
#    'referenceMessage': 'Ref.: APA_5',
#    'isMicrosite': True,
#    'mustShowLogo': False,
#    'micrositeCityName': 'sacavém e prior velho',
#    'commercialNamePhraseBlock': 'RoyalTeam Consultores',
#    'advertiserNameLink': '/pro/royalteamconsultores/',
#    'advertiserLogoUrl': None,
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  em Beato',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': '217920620',
#    'phoneRedirection': None,
#    'formattedContactPhone1': '966187827',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': '217920620',
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30635640,
#    'showProfessionalName': True,
#    'firstName': 'Rita Marino-Lourenço',
#    'lastName': None,
#    'commercialName': 'KW Ábaco',
#    'referenceMessage': 'Ref.: 1196-2853',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'areeiro',
#    'commercialNamePhraseBlock': 'KW Ábaco',
#    'advertiserNameLink': '/pro/kwabaco/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/10/6d/62/kwabaco.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T4 à venda  em Bairro Azul - Parque Eduardo VII',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215554935',
#    'formattedContactPhone1': '215554935',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30634643,
#    'showProfessionalName': True,
#    'firstName': 'Homelovers',
#    'lastName': '.',
#    'commercialName': 'HomeLovers',
#    'referenceMessage': 'Ref.: REF: A151657',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'santa maria maior',
#    'commercialNamePhraseBlock': 'HomeLovers',
#    'advertiserNameLink': '/pro/homelovers/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/fc/50/b1/homelovers.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  em Alvalade',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215561558',
#    'formattedContactPhone1': '215561558',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30635936,
#    'showProfessionalName': True,
#    'firstName': 'SILFIDÚCIA',
#    'lastName': None,
#    'commercialName': 'Silfiducia',
#    'referenceMessage': 'Ref.: A2626',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'santo antónio',
#    'commercialNamePhraseBlock': 'Silfiducia',
#    'advertiserNameLink': '/pro/silfiducia-sociedade-de-mediacao-imobiliaria/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/f3/c4/2f/silfiducia-sociedade-de-mediacao-imobiliaria.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  em Bairro Alto - Encarnação',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215552748',
#    'formattedContactPhone1': '215552748',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30634116,
#    'showProfessionalName': True,
#    'firstName': 'Prestige',
#    'lastName': None,
#    'commercialName': 'Remax Prestige',
#    'referenceMessage': 'Ref.: 123751015-250',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'alvalade',
#    'commercialNamePhraseBlock': 'Remax Prestige',
#    'advertiserNameLink': '/pro/remax-prestige/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/c0/d2/e6/remax-prestige.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  em Alcântara',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215564572',
#    'formattedContactPhone1': '215564572',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30588615,
#    'showProfessionalName': True,
#    'firstName': 'ERA Alcântara/Ajuda & ERA Belém/Restelo',
#    'lastName': None,
#    'commercialName': 'ERA Alcântara/Ajuda & ERA Belém/Restelo',
#    'referenceMessage': 'Ref.: 011200137',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'alcântara',
#    'commercialNamePhraseBlock': 'ERA Alcântara/Ajuda & ERA Belém/Restelo',
#    'advertiserNameLink': '/pro/era-alcantara-restelo/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/bf/d1/11/era-alcantara-restelo.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  em Alcântara',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215564572',
#    'formattedContactPhone1': '215564572',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30596545,
#    'showProfessionalName': True,
#    'firstName': 'ERA Alcântara/Ajuda & ERA Belém/Restelo',
#    'lastName': None,
#    'commercialName': 'ERA Alcântara/Ajuda & ERA Belém/Restelo',
#    'referenceMessage': 'Ref.: 011200138',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'alcântara',
#    'commercialNamePhraseBlock': 'ERA Alcântara/Ajuda & ERA Belém/Restelo',
#    'advertiserNameLink': '/pro/era-alcantara-restelo/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/bf/d1/11/era-alcantara-restelo.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  em Centro',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '265560937',
#    'formattedContactPhone1': '265560937',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30635487,
#    'showProfessionalName': True,
#    'firstName': 'Villas',
#    'lastName': 'Prestige',
#    'commercialName': 'Villa Prestige',
#    'referenceMessage': 'Ref.: Vp0129',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'castelo (sesimbra)',
#    'commercialNamePhraseBlock': 'Villa Prestige',
#    'advertiserNameLink': '/pro/villa-prestige/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/eb/ed/db/villa-prestige.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  em Campo Grande',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215552748',
#    'formattedContactPhone1': '215552748',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30634126,
#    'showProfessionalName': True,
#    'firstName': 'Prestige',
#    'lastName': None,
#    'commercialName': 'Remax Prestige',
#    'referenceMessage': 'Ref.: 123751027-307',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'alvalade',
#    'commercialNamePhraseBlock': 'Remax Prestige',
#    'advertiserNameLink': '/pro/remax-prestige/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/c0/d2/e6/remax-prestige.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  na rua Jorge Álvares',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215555638',
#    'formattedContactPhone1': '215555638',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30638784,
#    'showProfessionalName': True,
#    'firstName': 'DUPLEX - Lisbon Real Estate',
#    'lastName': None,
#    'commercialName': 'Duplex Lisbon Real State',
#    'referenceMessage': 'Ref.: APA_1264',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'algés - linda-a-velha - cruz quebrada - dafundo',
#    'commercialNamePhraseBlock': 'Duplex Lisbon Real State',
#    'advertiserNameLink': '/pro/duplex-lisbon-real-state/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/6b/5f/f5/duplex-lisbon-real-state.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda ,   Av. afonso III',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': '212508833',
#    'phoneRedirection': '210054102',
#    'formattedContactPhone1': '210054102',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': '212508833',
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30639988,
#    'showProfessionalName': True,
#    'firstName': 'FunnyHouse',
#    'lastName': None,
#    'commercialName': 'funnyhouse',
#    'referenceMessage': 'Ref.: 11253 A',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'são domingos de benfica',
#    'commercialNamePhraseBlock': 'funnyhouse',
#    'advertiserNameLink': '/pro/funnyhouse/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/c8/01/e9/funnyhouse.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  na rua Sebastião Saraiva e Silva',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215558064',
#    'formattedContactPhone1': '215558064',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30633505,
#    'showProfessionalName': True,
#    'firstName': 'Cristina',
#    'lastName': 'Amaral',
#    'commercialName': 'Propostas Imobiliárias',
#    'referenceMessage': 'Anúncio: 30633505',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'parque das nações',
#    'commercialNamePhraseBlock': 'Propostas Imobiliárias',
#    'advertiserNameLink': '/pro/propostas-imobiliarias/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/42/57/38/propostas-imobiliarias.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  na rua do Bom Pastor',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '210053120',
#    'formattedContactPhone1': '210053120',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30638589,
#    'showProfessionalName': True,
#    'firstName': 'HABITA',
#    'lastName': None,
#    'commercialName': 'Habita - Arrendar | Comprar | Investir - Imobiliária - Lisboa',
#    'referenceMessage': 'Ref.: JF082002',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'arroios',
#    'commercialNamePhraseBlock': 'Habita - Arrendar | Comprar | Investir - Imobiliária - Lisboa',
#    'advertiserNameLink': '/pro/habita-arrendar-comprar-investir/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/b5/2a/7c/habita-arrendar-comprar-investir.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  em Castelo - Mouraria',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215557625',
#    'formattedContactPhone1': '215557625',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 29847229,
#    'showProfessionalName': True,
#    'firstName': 'Castelhana',
#    'lastName': None,
#    'commercialName': 'Castelhana Imobiliário Portugal',
#    'referenceMessage': 'Ref.: 8293',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'santa maria maior',
#    'commercialNamePhraseBlock': 'Castelhana Imobiliário Portugal',
#    'advertiserNameLink': '/pro/castelhana/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/9a/fd/0e/castelhana.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  em Bairro Alto - Encarnação',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215553057',
#    'formattedContactPhone1': '215553057',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30638683,
#    'showProfessionalName': True,
#    'firstName': "Porta da Frente Christie's",
#    'lastName': None,
#    'commercialName': 'Porta da Frente',
#    'referenceMessage': 'Ref.: PF22465',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'cascais e estoril',
#    'commercialNamePhraseBlock': 'Porta da Frente',
#    'advertiserNameLink': '/pro/porta-da-frente-christies-international-real-estate/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/ed/c2/fc/porta-da-frente-christies-international-real-estate.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  na avenida Conselheiro Barjona de Freitas',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215553058',
#    'formattedContactPhone1': '215553058',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30636530,
#    'showProfessionalName': True,
#    'firstName': 'Century21 Colombo',
#    'lastName': None,
#    'commercialName': 'Century 21 Colombo',
#    'referenceMessage': 'Ref.: C0222-02972',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'são domingos de benfica',
#    'commercialNamePhraseBlock': 'Century 21 Colombo',
#    'advertiserNameLink': '/pro/century-21-colombo/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/91/a1/26/century-21-colombo.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  em Campo Pequeno - Nossa Senhora de Fátima',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215562549',
#    'formattedContactPhone1': '215562549',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30638811,
#    'showProfessionalName': True,
#    'firstName': 'LUX & LUST, MEDIAÇÃO IMOBILIÁRIA, LDA',
#    'lastName': None,
#    'commercialName': 'Lux Properties',
#    'referenceMessage': 'Ref.: ESF09',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'estoril',
#    'commercialNamePhraseBlock': 'Lux Properties',
#    'advertiserNameLink': '/pro/lux-lust/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/5f/e8/89/lux-lust.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': ' Casa ou moradia à venda  em Parque das Nações',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215550932',
#    'formattedContactPhone1': '215550932',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30637962,
#    'showProfessionalName': True,
#    'firstName': 'Inside Living - Mediação Imobiliária, Lda.',
#    'lastName': None,
#    'commercialName': 'Inside Living - Luxury Estate',
#    'referenceMessage': 'Ref.: L50961',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'alcabideche',
#    'commercialNamePhraseBlock': 'Inside Living - Luxury Estate',
#    'advertiserNameLink': '/pro/inside-livingmediacaoimobiliaria/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/00/fc/f9/inside-livingmediacaoimobiliaria.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  em Alcântara',
#    'showAdvertiserName': False,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '210062190',
#    'formattedContactPhone1': '210062190',
#    'showFormattedContactPhone2': False,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30637765,
#    'showProfessionalName': False,
#    'firstName': 'Método',
#    'lastName': 'Portugal Real Estate',
#    'commercialName': 'Método Portugal Real Estate',
#    'referenceMessage': 'Ref.: mi13092-16',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'santa maria maior',
#    'commercialNamePhraseBlock': 'Método Portugal Real Estate',
#    'advertiserNameLink': '/pro/metodopre/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/f0/9d/4a/metodopre.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  em Alcântara',
#    'showAdvertiserName': False,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '210062190',
#    'formattedContactPhone1': '210062190',
#    'showFormattedContactPhone2': False,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30637759,
#    'showProfessionalName': False,
#    'firstName': 'Método',
#    'lastName': 'Portugal Real Estate',
#    'commercialName': 'Método Portugal Real Estate',
#    'referenceMessage': 'Ref.: mi13092-10',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'santa maria maior',
#    'commercialNamePhraseBlock': 'Método Portugal Real Estate',
#    'advertiserNameLink': '/pro/metodopre/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/f0/9d/4a/metodopre.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T4 à venda  em Entrecampos',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': '214035028',
#    'phoneRedirection': None,
#    'formattedContactPhone1': '964421165',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': '214035028',
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30637670,
#    'showProfessionalName': True,
#    'firstName': 'Ana Azevedo Neves',
#    'lastName': None,
#    'commercialName': 'kw area',
#    'referenceMessage': 'Ref.: 1204-1329',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'campo de ourique',
#    'commercialNamePhraseBlock': 'kw area',
#    'advertiserNameLink': '/pro/kw-area/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/2c/9b/b1/kw-area.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda ,   Av. Afonso III',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': '212508833',
#    'phoneRedirection': '210054102',
#    'formattedContactPhone1': '210054102',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': '212508833',
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30640081,
#    'showProfessionalName': True,
#    'firstName': 'FunnyHouse',
#    'lastName': None,
#    'commercialName': 'funnyhouse',
#    'referenceMessage': 'Ref.: 11264',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'são domingos de benfica',
#    'commercialNamePhraseBlock': 'funnyhouse',
#    'advertiserNameLink': '/pro/funnyhouse/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/c8/01/e9/funnyhouse.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  na avenida João Crisóstomo s/n',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215552931',
#    'formattedContactPhone1': '215552931',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30639658,
#    'showProfessionalName': True,
#    'firstName': 'Latina II',
#    'lastName': None,
#    'commercialName': 'LATINA II',
#    'referenceMessage': 'Ref.: 120992285-11',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'avenidas novas',
#    'commercialNamePhraseBlock': 'LATINA II',
#    'advertiserNameLink': '/pro/latina-ii/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/56/b1/09/latina-ii.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  na avenida Pádua s/n',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215554759',
#    'formattedContactPhone1': '215554759',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30639545,
#    'showProfessionalName': True,
#    'firstName': 'Expo',
#    'lastName': None,
#    'commercialName': 'RE/MAX Expo',
#    'referenceMessage': 'Ref.: 120611194-1406',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'Parque das Nações',
#    'commercialNamePhraseBlock': 'RE/MAX Expo',
#    'advertiserNameLink': '/pro/remax-expo/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/37/6f/80/remax-expo.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T5 à venda  na avenida Visconde de Valmor',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215556054',
#    'formattedContactPhone1': '215556054',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30640222,
#    'showProfessionalName': True,
#    'firstName': 'Luiz',
#    'lastName': 'Maia',
#    'commercialName': 'Maia International Properties',
#    'referenceMessage': 'Anúncio: 30640222',
#    'isMicrosite': True,
#    'mustShowLogo': False,
#    'micrositeCityName': 'santo antónio',
#    'commercialNamePhraseBlock': 'Maia International Properties',
#    'advertiserNameLink': '/pro/maia-international-properties/',
#    'advertiserLogoUrl': None,
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  na avenida João Crisóstomo',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
# ...
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'estrela',
#    'commercialNamePhraseBlock': 'Remax Team4u',
#    'advertiserNameLink': '/pro/remax-4u/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/bc/06/40/remax-4u.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  na avenida do Brasil',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215552796',
#    'formattedContactPhone1': '215552796',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30634246,
#    'showProfessionalName': True,
#    'firstName': 'ConviCtus',
#    'lastName': None,
#    'commercialName': 'Remax CONVICTUS',
#    'referenceMessage': 'Ref.: 121491571-22',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'alvalade',
#    'commercialNamePhraseBlock': 'Remax CONVICTUS',
#    'advertiserNameLink': '/pro/remax-convictus/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/d4/c7/ef/remax-convictus.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T4 à venda  no passeio Âncoras',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215563194',
#    'formattedContactPhone1': '215563194',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30634136,
#    'showProfessionalName': True,
#    'firstName': 'Golden Line II',
#    'lastName': None,
#    'commercialName': 'Remax Golden Line II',
#    'referenceMessage': 'Ref.: 125191046-20',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'campo de ourique',
#    'commercialNamePhraseBlock': 'Remax Golden Line II',
#    'advertiserNameLink': '/pro/remax-golden-line-2/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/f4/51/7b/remax-golden-line-2.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T1 à venda  em Ajuda',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215552785',
#    'formattedContactPhone1': '215552785',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30634165,
#    'showProfessionalName': True,
#    'firstName': 'Action',
#    'lastName': None,
#    'commercialName': 'RE/MAX - Action',
#    'referenceMessage': 'Ref.: 123171251-56',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'são domingos de benfica',
#    'commercialNamePhraseBlock': 'RE/MAX - Action',
#    'advertiserNameLink': '/pro/remax-action/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/82/fe/0d/remax-action.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  em Campo de Ourique',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '289983154',
#    'formattedContactPhone1': '289983154',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30636107,
#    'showProfessionalName': True,
#    'firstName': 'LUXAVENUE',
#    'lastName': None,
#    'commercialName': 'LUXAVENUE - Imobiliária',
#    'referenceMessage': 'Ref.: SALE-KW-02013',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'Loule',
#    'commercialNamePhraseBlock': 'LUXAVENUE - Imobiliária',
#    'advertiserNameLink': '/pro/luxavenue-imobiliario/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/a4/9c/5f/luxavenue-imobiliario.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T5 à venda  em Baixa',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215552945',
#    'formattedContactPhone1': '215552945',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30634206,
#    'showProfessionalName': True,
#    'firstName': 'SiimGroup Lumiar',
#    'lastName': None,
#    'commercialName': 'Remax Lumiar',
#    'referenceMessage': 'Ref.: 120531237-405',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'lumiar',
#    'commercialNamePhraseBlock': 'Remax Lumiar',
#    'advertiserNameLink': '/pro/lumiar/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/df/7d/07/lumiar.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda ,   Praça da Viscondessa dos Olivais s/n',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215554759',
#    'formattedContactPhone1': '215554759',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30634007,
#    'showProfessionalName': True,
#    'firstName': 'Expo',
#    'lastName': None,
#    'commercialName': 'RE/MAX Expo',
#    'referenceMessage': 'Ref.: 120611245-305',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'Parque das Nações',
#    'commercialNamePhraseBlock': 'RE/MAX Expo',
#    'advertiserNameLink': '/pro/remax-expo/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/37/6f/80/remax-expo.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T2 à venda  em Telheiras',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215568739',
#    'formattedContactPhone1': '215568739',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30633966,
#    'showProfessionalName': True,
#    'firstName': 'Smart In',
#    'lastName': None,
#    'commercialName': 'Re/max Smart In',
#    'referenceMessage': 'Ref.: 125571021-2',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'cascais e estoril',
#    'commercialNamePhraseBlock': 'Re/max Smart In',
#    'advertiserNameLink': '/pro/remaxin/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/6d/1a/8f/remaxin.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  em São João de Brito',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '225558678',
#    'formattedContactPhone1': '225558678',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30633481,
#    'showProfessionalName': True,
#    'firstName': 'André REIS',
#    'lastName': None,
#    'commercialName': 'IAD Portugal',
#    'referenceMessage': 'Ref.: 42776',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'moreira',
#    'commercialNamePhraseBlock': 'IAD Portugal',
#    'advertiserNameLink': '/pro/iad-portugal/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/87/7a/01/iad-portugal.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': False,
#    'agencyIsABank': None,
#    'shortDescription': 'Apartamento T3 à venda  na rua Helena Vaz da Silva, 5',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 1,
#    'phone2': None,
#    'phoneRedirection': None,
#    'formattedContactPhone1': '926292001',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': 'apartamento',
#    'newDevelopmentDirectory': False,
#    'adId': 30633159,
#    'showProfessionalName': True,
#    'firstName': 'Ana Ambrozio',
#    'lastName': None,
#    'commercialName': '',
#    'referenceMessage': 'Anúncio: 30633159',
#    'isMicrosite': False,
#    'mustShowLogo': None,
#    'micrositeCityName': None,
#    'commercialNamePhraseBlock': None,
#    'advertiserNameLink': None,
#    'advertiserLogoUrl': None,
#    'isVirtualMicrosite': None,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T5 à venda  na rua Cidade de Bolama s/n',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215552673',
#    'formattedContactPhone1': '215552673',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30634367,
#    'showProfessionalName': True,
#    'firstName': 'Vantagem Central',
#    'lastName': None,
#    'commercialName': 'RE/MAX Vantagem Central',
#    'referenceMessage': 'Ref.: 121961620-38',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'santo antónio',
#    'commercialNamePhraseBlock': 'RE/MAX Vantagem Central',
#    'advertiserNameLink': '/pro/remax-vantagem-central/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/48/67/2b/remax-vantagem-central.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': True,
#    'agencyIsABank': False,
#    'shortDescription': 'Apartamento T3 à venda  em São Domingos de Benfica',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': True,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 2,
#    'phone2': None,
#    'phoneRedirection': '215552785',
#    'formattedContactPhone1': '215552785',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': None,
#    'newDevelopmentDirectory': False,
#    'adId': 30634154,
#    'showProfessionalName': True,
#    'firstName': 'Action',
#    'lastName': None,
#    'commercialName': 'RE/MAX - Action',
#    'referenceMessage': 'Ref.: 123171059-77',
#    'isMicrosite': True,
#    'mustShowLogo': True,
#    'micrositeCityName': 'são domingos de benfica',
#    'commercialNamePhraseBlock': 'RE/MAX - Action',
#    'advertiserNameLink': '/pro/remax-action/',
#    'advertiserLogoUrl': 'https://st3.idealista.pt/82/fe/0d/remax-action.gif',
#    'isVirtualMicrosite': False,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}},
#  {'message': None,
#   'result': 'OK',
#   'errorCode': None,
#   'data': {'isInvoiceAd': False,
#    'isAdProfessional': False,
#    'agencyIsABank': None,
#    'shortDescription': 'Apartamento T4 à venda  na rua Francisco Franco, 6',
#    'showAdvertiserName': True,
#    'showEmailContactMethod': False,
#    'showPhoneContactMethod': True,
#    'contactMessage': None,
#    'contactDate': None,
#    'contactType': 1,
#    'phone2': None,
#    'phoneRedirection': None,
#    'formattedContactPhone1': '962831735',
#    'showFormattedContactPhone2': True,
#    'formattedContactPhone2': None,
#    'adTypologyName': 'apartamento',
#    'newDevelopmentDirectory': False,
#    'adId': 30636348,
#    'showProfessionalName': True,
#    'firstName': 'João Fiadeiro',
#    'lastName': None,
#    'commercialName': '',
#    'referenceMessage': 'Anúncio: 30636348',
#    'isMicrosite': False,
#    'mustShowLogo': None,
#    'micrositeCityName': None,
#    'commercialNamePhraseBlock': None,
#    'advertiserNameLink': None,
#    'advertiserLogoUrl': None,
#    'isVirtualMicrosite': None,
#    'avatarUrl': '',
#    'hasBeenContactedBefore': False,
#    'redirectToConversationUrl': None,
#    'blockingStatusInfo': None,
#    'listingSearchUrl': '',
#    'adRealEstateDeveloper': False}}]
