# %%
import requests
from bs4 import BeautifulSoup
import textwrap
from datetime import datetime
import json
import urllib

# %%
with open("scrap.json") as json_file:
    scrap_json = json.load(json_file)
print('Loaded scrap json:\n\tUID: {}'.format(scrap_json['uid']))
# Out:
# Loaded scrap json:
# 	UID: 55c5fd9dadafwmbu5lzwmd2vx5d2agxggm894hqnht8

# %% [markdown]
# ## Ad scrapping

# %%
def json_to_cookie(cookie_json):
    return '; '.join(['{}={}'.format(k,v) for k, v in cookie_json.items()])
#print(cookie_str, new_cookie_str)

#print compare
def compare_print(a, b):
    print('{:>55} | {:<55}'.format('A','B'))
    print('-'*113)
    for i in range(len(a)):
        a_el = ''
        b_el = ''
        if(len(a) > i):
            a_el = a[i]
        if(len(b) > i):
            b_el = b[i]
        print('{:<55} | {:<55}'.format(a_el,b_el))

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'cookie': json_to_cookie(scrap_json['cookie'])
}

# %%
articles = []

host = 'https://www.idealista.pt'
path = 'en/comprar-casas'
region = 'lisboa'
params = ['com-tamanho-min_100','publicado_ultimas-48-horas']
url = '/' + '/'.join([path,region,','.join(params)])

i = 0
while url:
    i += 1
    url = host + url
    print('{}) Request URL: {}'.format(i, url))
    
    req = requests.get(url, headers)
    if(req.status_code != 200):
        print('{}) HTTP Code {}\n\tBody: {}'.format(i, req.status_code,req.text))
        break
    
    soup = BeautifulSoup(req.content, 'html.parser')
    
    articles += soup.find_all('article')
    
    print('\tArticles/Ads found: {}'.format(len(articles)))
    pagination = soup.find('div', 'pagination')

    next_page_tag = pagination.find('a', 'icon-arrow-right-after')
    url = next_page_tag.get('href') if next_page_tag else None
# Out:
# 1) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas
# 	Articles/Ads found: 32
# 2) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-2
# 	Articles/Ads found: 64
# 3) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-3
# 	Articles/Ads found: 96
# 4) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-4
# 	Articles/Ads found: 128
# 5) Request URL: https://www.idealista.pt/en/comprar-casas/lisboa/com-tamanho-min_100,publicado_ultimas-48-horas/pagina-5
# 	Articles/Ads found: 138

# %%
#print(articles[0].prettify())

items = []
for ad in articles:
    # .info-data-price
    if('adv' in ad.attrs['class']):
        continue
    item_price = ad.find('span', class_='item-price')
    item_detail = ad.find_all('span', class_='item-detail')
    item_link = ad.find('a', class_='item-link')
    item_title = item_link.get('title')
    item_id = ad.get('data-adid')
    
    price = int(item_price.get_text()[:-1].replace(',',''))
    address = urllib.parse.quote(item_title[item_title.find(' in ')+4:]) if item_title.find(' in ') != - 1 else item_title
    size = int(item_detail[1].get_text()[:-3].replace(',','')) if len(item_detail) > 1 else print('{} Failed to fetch area!'.format(item_id))
    item_url = '{}{}'.format(host,item_link.get('href'))

    items.append({
        'price': price,
        'address': address,
        'id': item_id,
        'size': size,
        'url': item_url
    })
    #print(json.dumps(items_dict[item_id], indent=4, sort_keys=True))
print('Ads parsed: {}'.format(len(items)))
# Out:
# Ads parsed: 129

# %%
time_format = '%d-%m-%Y_%H:%M:%S_scrap'
data_path = './data_scrap'

now = datetime.now()
s2 = now.strftime(time_format)

f = open(data_path + '/' + s2 + ".json","w")
f.write(json.dumps(items))
f.close()

# %% [markdown]
# ## Ad GeoLocation (scrapped from Idealista)

# %%
import urllib
# TODO go around the map taking the places
params_dict = dict(
    locationUri='lisboa',
    typology='1',
    operation='1',
    zoom='5',
    northEast='54.17960751741163,16.15620517730715',
    southWest='19.08984486221779,-34.46879482269287',
    uid=scrap_json['uid'],
    adfilter_pricemin='default',
    adfilter_price='700000',
    adfilter_area='100',
    adfilter_areamax='default',
    adfilter_published='default'
)
params_dict['solo-favoritos'] = 'false'
params = urllib.parse.urlencode(params_dict, doseq=True)

host = 'https://www.idealista.pt'
path = '/ajax/listingcontroller/listingmapajax.ajax'

new_url = '{}{}?{}'.format(host,path,params)


req = requests.get(new_url, headers)
print(req)
ajax_listing_json = req.json()
json_resp = ajax_listing_json['jsonResponse']

print(json_resp.keys(), len(json_resp['map']['items']))

print(len(json_resp['map']['items']), json_resp['listingTotalResults'])
for geo in json_resp['map']['items']:
    print(geo['adId'])
# Out:
# <Response [200]>
# dict_keys(['valueH1', 'description', 'total', 'result', 'errorMessage', 'searchFeaturesPhrase', 'searchPhrase', 'howmany', 'search', 'breadcrumbUrlValue', 'breadcrumbUrlAllMunicipalitiesLevel', 'mapSearchUrl', 'listingSearchUrl', 'rentListingSearchUrl', 'saleListingSearchUrlMobile', 'newDevelopmentUrlMobile', 'newDevelopmentUrl', 'saleListingSearchUrl', 'rentListingSearchUrlMobile', 'pagetarget', 'searchTotalsUrl', 'searchWithoutFilters', 'listingTotalResults', 'listingPriceByArea', 'map', 'existAlert']) 1300
# 1300 4.124
# 30369970
# 29170910
# 29449093
# 29606285
# 30336026
# 29856575
# 30413464
# 30575411
# 29633853
# 30249609
# 29632527
# 30403495
# 30481343
# 30263875
# 30588189
# 30594915
# 29382829
# 30384609
# 29771448
# 30478576
# 30481787
# 30061575
# 30061584
# 30515854
# 29737469
# 30457836
# 30301706
# 30111228
# 30240524
# 30295427
# 30109560
# 30115531
# 30075628
# 30287304
# 30208588
# 30212211
# 29929845
# 30430610
# 30430606
# 30171996
# 30171988
# 30174601
# 30172474
# 30181590
# 30171983
# 30171997
# 30164581
# 30310415
# 29800728
# 30479405
# 30323949
# 30323972
# 30185612
# 30524465
# 30531230
# 30272094
# 30276813
# 30560401
# 30545872
# 30479487
# 30472806
# 30457426
# 30467595
# 30324140
# 30545866
# 30548848
# 30548363
# 30548367
# 30548851
# 30549566
# 30549542
# 30528230
# 30524464
# 30548965
# 30328212
# 30579008
# 30579022
# 30208557
# 30466286
# 29731533
# 29453622
# 30529252
# 29763095
# 30454806
# 30543734
# 29124847
# 29942299
# 30407513
# 30244983
# 29901278
# 28533192
# 30185696
# 30355460
# 29690553
# 30530832
# 30360957
# 30527222
# 29874538
# 27880351
# 30192049
# 28644559
# 30334279
# 30334297
# 30458746
# 30508969
# 30387804
# 30507374
# 29871813
# 29974076
# 30386616
# 30564813
# 30427794
# 28950128
# 28427317
# 30471613
# 29125295
# 29996032
# 30607761
# 30518724
# 30582004
# 30589874
# 30590330
# 30393506
# 30623903
# 30476559
# 30026646
# 30395325
# 30180180
# 30622681
# 29840391
# 30513736
# 30086546
# 30598509
# 30121992
# 30084195
# 30338615
# 30462413
# 30596045
# 29866721
# 30456614
# 30412700
# 30476923
# 30254626
# 30255032
# 30290000
# 30197254
# 30214392
# 30617955
# 30617953
# 30617961
# 30615472
# 30302129
# 30289821
# 30601027
# 30146813
# 30527775
# 30620665
# 30527742
# 30542088
# 30611718
# 30576760
# 30576758
# 30121100
# 28564421
# 30241009
# 30309617
# 29906167
# 30576773
# 30334495
# 30346634
# 30492550
# 30500660
# 30375722
# 30291274
# 30102806
# 30608349
# 30474629
# 30324779
# 30305317
# 30438889
# 30608348
# 30275548
# 30375716
# 30209950
# 30611881
# 30049385
# 30010235
# 29464971
# 29387635
# 29744068
# 30577048
# 30231442
# 30398450
# 30216992
# 30577047
# 30275729
# 30568563
# 30166904
# 30536538
# 30389488
# 30396704
# 29967530
# 28648550
# 30536519
# 30620733
# 30386738
# 30209952
# 30166907
# 30010197
# 29957901
# 30216922
# 30360200
# 30495284
# 30581240
# 30581242
# 30549803
# 30068319
# 30294170
# 30010223
# 30492606
# 30001598
# 30611796
# 30231392
# 30221654
# 30591248
# 30448138
# 30131617
# 30630305
# 29774463
# 29771307
# 30558745
# 30436617
# 30495374
# 29636842
# 28930230
# 30593812
# 30144286
# 29348192
# 30499228
# 30598846
# 30437542
# 29064119
# 30253764
# 29064171
# 30127466
# 29802038
# 30333241
# 30581571
# 28859277
# 30444286
# 28457823
# 30361365
# 30561311
# 28737318

# %% [markdown]
# ## Join Ad and GeoLocation

# %%
items_dict = {}
for it in items:
    items_dict[it['id']] = it

geo_dict = {}
for geo in json_resp['map']['items']:
    geo_dict[geo['adId']] = geo
    
    if str(geo['adId']) in items_dict:
        items_dict[str(geo['adId'])]['geo'] = { 'latitude': geo['latitude'], 'longitude': geo['longitude'] }
        #print(items_dict[str(geo['adId'])])
print(json.dumps(items_dict, indent=4, sort_keys=True))
# Out:
# {
#     "29807402": {
#         "address": "Santos-o-Velho%20-%20Madragoa%2C%20Estrela",
#         "id": "29807402",
#         "price": 900000,
#         "size": 109,
#         "url": "https://www.idealista.pt/en/imovel/29807402/"
#     },
#     "30028049": {
#         "address": "Areeiro%2C%20Lisboa",
#         "id": "30028049",
#         "price": 950000,
#         "size": 343,
#         "url": "https://www.idealista.pt/en/imovel/30028049/"
#     },
#     "30180991": {
#         "address": "Anjos%2C%20Arroios",
#         "id": "30180991",
#         "price": 610000,
#         "size": 132,
#         "url": "https://www.idealista.pt/en/imovel/30180991/"
#     },
#     "30454590": {
#         "address": "rua%20Cidade%20de%20Nampula%2C%20Olivais%2C%20Lisboa",
#         "id": "30454590",
#         "price": 598000,
#         "size": 202,
#         "url": "https://www.idealista.pt/en/imovel/30454590/"
#     },
#     "30569749": {
#         "address": "Bairro%20Alto%20-%20Encarna%C3%A7%C3%A3o%2C%20Miseric%C3%B3rdia",
#         "id": "30569749",
#         "price": 986000,
#         "size": 145,
#         "url": "https://www.idealista.pt/en/imovel/30569749/"
#     },
#     "30588615": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30588615",
#         "price": 545000,
#         "size": 112,
#         "url": "https://www.idealista.pt/en/imovel/30588615/"
#     },
#     "30596545": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30596545",
#         "price": 790000,
#         "size": 195,
#         "url": "https://www.idealista.pt/en/imovel/30596545/"
#     },
#     "30598354": {
#         "address": "Campo%20Grande%2C%20Alvalade",
#         "id": "30598354",
#         "price": 1372000,
#         "size": 350,
#         "url": "https://www.idealista.pt/en/imovel/30598354/"
#     },
#     "30613524": {
#         "address": "avenida%20Infante%20Santo%2C%20Prazeres%2C%20Estrela",
#         "geo": {
#             "latitude": 38.7093094,
#             "longitude": -9.1663274
#         },
#         "id": "30613524",
#         "price": 525000,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30613524/"
#     },
#     "30613704": {
#         "address": "S%C3%A3o%20Jo%C3%A3o%20de%20Brito%2C%20Alvalade",
#         "id": "30613704",
#         "price": 1650000,
#         "size": 342,
#         "url": "https://www.idealista.pt/en/imovel/30613704/"
#     },
#     "30614879": {
#         "address": "Pena%2C%20Arroios",
#         "id": "30614879",
#         "price": 632500,
#         "size": 138,
#         "url": "https://www.idealista.pt/en/imovel/30614879/"
#     },
#     "30618250": {
#         "address": "Prazeres%2C%20Estrela",
#         "id": "30618250",
#         "price": 1300000,
#         "size": 270,
#         "url": "https://www.idealista.pt/en/imovel/30618250/"
#     },
#     "30625028": {
#         "address": "avenida%20Jo%C3%A3o%20Paulo%20II%2C%207%2C%20Marvila%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7437952,
#             "longitude": -9.1139385
#         },
#         "id": "30625028",
#         "price": 275000,
#         "size": 112,
#         "url": "https://www.idealista.pt/en/imovel/30625028/"
#     },
#     "30625338": {
#         "address": "avenida%20Defensores%20de%20Chaves%2C%203%2C%20Saldanha%20-%20Picoas%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30625338",
#         "price": 509000,
#         "size": 101,
#         "url": "https://www.idealista.pt/en/imovel/30625338/"
#     },
#     "30626981": {
#         "address": "Anjos%2C%20Arroios",
#         "id": "30626981",
#         "price": 558000,
#         "size": 124,
#         "url": "https://www.idealista.pt/en/imovel/30626981/"
#     },
#     "30627243": {
#         "address": "rua%20S%C3%A3o%20Bento%20Menni%2C%203%2C%20Telheiras%2C%20Lumiar",
#         "id": "30627243",
#         "price": 480000,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30627243/"
#     },
#     "30628305": {
#         "address": "avenida%20David%20Mour%C3%A3o-Ferreira%2C%2063%2C%20Alto%20do%20Lumiar%2C%20Lumiar",
#         "id": "30628305",
#         "price": 477500,
#         "size": 144,
#         "url": "https://www.idealista.pt/en/imovel/30628305/"
#     },
#     "30629649": {
#         "address": "avenida%20Jo%C3%A3o%20XXI%2C%2072%2C%20Areeiro%2C%20Lisboa",
#         "id": "30629649",
#         "price": 820000,
#         "size": 180,
#         "url": "https://www.idealista.pt/en/imovel/30629649/"
#     },
#     "30629734": {
#         "address": "estrada%20da%20Luz%2C%2094%2C%20S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30629734",
#         "price": 475000,
#         "size": 126,
#         "url": "https://www.idealista.pt/en/imovel/30629734/"
#     },
#     "30630063": {
#         "address": "Campo%20de%20Ourique%2C%20Lisboa",
#         "id": "30630063",
#         "price": 450000,
#         "size": 116,
#         "url": "https://www.idealista.pt/en/imovel/30630063/"
#     },
#     "30630103": {
#         "address": "Igreja%20-%20Mercado%20-%20Pedralvas%2C%20Benfica",
#         "id": "30630103",
#         "price": 350000,
#         "size": 103,
#         "url": "https://www.idealista.pt/en/imovel/30630103/"
#     },
#     "30630305": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "geo": {
#             "latitude": 38.7248706,
#             "longitude": -9.1669055
#         },
#         "id": "30630305",
#         "price": 485000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30630305/"
#     },
#     "30630372": {
#         "address": "rua%20Francisco%20de%20Andrade%2C%20Alvalade%2C%20Alvalade",
#         "id": "30630372",
#         "price": 899900,
#         "size": 160,
#         "url": "https://www.idealista.pt/en/imovel/30630372/"
#     },
#     "30630532": {
#         "address": "avenida%20Almirante%20Reis%2C%20Anjos%2C%20Arroios",
#         "id": "30630532",
#         "price": 550000,
#         "size": 165,
#         "url": "https://www.idealista.pt/en/imovel/30630532/"
#     },
#     "30631007": {
#         "address": "Ajuda%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7116262,
#             "longitude": -9.2048511
#         },
#         "id": "30631007",
#         "price": 675000,
#         "size": 149,
#         "url": "https://www.idealista.pt/en/imovel/30631007/"
#     },
#     "30631136": {
#         "address": "Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30631136",
#         "price": 549900,
#         "size": 139,
#         "url": "https://www.idealista.pt/en/imovel/30631136/"
#     },
#     "30631161": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "geo": {
#             "latitude": 38.740486,
#             "longitude": -9.1516526
#         },
#         "id": "30631161",
#         "price": 640000,
#         "size": 150,
#         "url": "https://www.idealista.pt/en/imovel/30631161/"
#     },
#     "30631209": {
#         "address": "T4 flat, Cal\u00e7ada de Santo Ant\u00f3nio, 16, Cora\u00e7\u00e3o de Jesus, Santo Ant\u00f3nio",
#         "id": "30631209",
#         "price": 830000,
#         "size": 175,
#         "url": "https://www.idealista.pt/en/imovel/30631209/"
#     },
#     "30631414": {
#         "address": "rua%20Carvalho%20Ara%C3%BAjo%2C%20Bairro%20dos%20Actores%20-%20Bar%C3%A3o%20Sabrosa%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30631414",
#         "price": 545000,
#         "size": 169,
#         "url": "https://www.idealista.pt/en/imovel/30631414/"
#     },
#     "30631628": {
#         "address": "rua%20Sousa%20Lopes%2C%20Entrecampos%2C%20Avenidas%20Novas",
#         "id": "30631628",
#         "price": 725000,
#         "size": 187,
#         "url": "https://www.idealista.pt/en/imovel/30631628/"
#     },
#     "30631632": {
#         "address": "T5 flat, Almirante Reis, Anjos, Arroios",
#         "id": "30631632",
#         "price": 340000,
#         "size": 140,
#         "url": "https://www.idealista.pt/en/imovel/30631632/"
#     },
#     "30631730": {
#         "address": "rua%20Carvalho%20Ara%C3%BAjo%2C%20Alameda%20-%20Pra%C3%A7a%20do%20Chile%20-%20Almirante%20Reis%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "geo": {
#             "latitude": 38.7356477,
#             "longitude": -9.1333428
#         },
#         "id": "30631730",
#         "price": 360000,
#         "size": 132,
#         "url": "https://www.idealista.pt/en/imovel/30631730/"
#     },
#     "30631732": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30631732",
#         "price": 1950000,
#         "size": 220,
#         "url": "https://www.idealista.pt/en/imovel/30631732/"
#     },
#     "30631784": {
#         "address": "travessa%20do%20Terreirinho%2C%20Castelo%20-%20Mouraria%2C%20Santa%20Maria%20Maior",
#         "id": "30631784",
#         "price": 450000,
#         "size": 155,
#         "url": "https://www.idealista.pt/en/imovel/30631784/"
#     },
#     "30631854": {
#         "address": "S%C3%A3o%20Sebasti%C3%A3o%20da%20Pedreira%2C%20Avenidas%20Novas",
#         "id": "30631854",
#         "price": 750000,
#         "size": 155,
#         "url": "https://www.idealista.pt/en/imovel/30631854/"
#     },
#     "30631928": {
#         "address": "Anjos%2C%20Arroios",
#         "geo": {
#             "latitude": 38.7234566,
#             "longitude": -9.1374664
#         },
#         "id": "30631928",
#         "price": 490000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30631928/"
#     },
#     "30631975": {
#         "address": "Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30631975",
#         "price": 2150000,
#         "size": 207,
#         "url": "https://www.idealista.pt/en/imovel/30631975/"
#     },
#     "30631976": {
#         "address": "rua%20Rosa%20Ara%C3%BAjo%2C%20Cora%C3%A7%C3%A3o%20de%20Jesus%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30631976",
#         "price": 1700000,
#         "size": 189,
#         "url": "https://www.idealista.pt/en/imovel/30631976/"
#     },
#     "30631986": {
#         "address": "Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30631986",
#         "price": 549900,
#         "size": 148,
#         "url": "https://www.idealista.pt/en/imovel/30631986/"
#     },
#     "30632035": {
#         "address": "Santa%20Engr%C3%A1cia%2C%20S%C3%A3o%20Vicente",
#         "id": "30632035",
#         "price": 350000,
#         "size": 104,
#         "url": "https://www.idealista.pt/en/imovel/30632035/"
#     },
#     "30632039": {
#         "address": "Alto%20de%20S%C3%A3o%20Jo%C3%A3o%20-%20Alto%20do%20Varej%C3%A3o%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30632039",
#         "price": 319000,
#         "size": 102,
#         "url": "https://www.idealista.pt/en/imovel/30632039/"
#     },
#     "30632046": {
#         "address": "Campo%20de%20Ourique%2C%20Lisboa",
#         "id": "30632046",
#         "price": 650000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30632046/"
#     },
#     "30632048": {
#         "address": "Alvalade%2C%20Alvalade",
#         "id": "30632048",
#         "price": 390000,
#         "size": 106,
#         "url": "https://www.idealista.pt/en/imovel/30632048/"
#     },
#     "30632242": {
#         "address": "Alvalade%2C%20Alvalade",
#         "id": "30632242",
#         "price": 379000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30632242/"
#     },
#     "30632243": {
#         "address": "Alvalade%2C%20Alvalade",
#         "id": "30632243",
#         "price": 379000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30632243/"
#     },
#     "30632457": {
#         "address": "rua%20Virg%C3%ADlio%20Correia%2C%20S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30632457",
#         "price": 540000,
#         "size": 163,
#         "url": "https://www.idealista.pt/en/imovel/30632457/"
#     },
#     "30632490": {
#         "address": "rua%20Cidade%20de%20Nampula%2C%20148%2C%20Olivais%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7644983,
#             "longitude": -9.1203962
#         },
#         "id": "30632490",
#         "price": 598000,
#         "size": 202,
#         "url": "https://www.idealista.pt/en/imovel/30632490/"
#     },
#     "30632494": {
#         "address": "Alto%20do%20Lumiar%2C%20Lumiar",
#         "id": "30632494",
#         "price": 425000,
#         "size": 133,
#         "url": "https://www.idealista.pt/en/imovel/30632494/"
#     },
#     "30632562": {
#         "address": "Alto%20do%20Lumiar%2C%20Lumiar",
#         "id": "30632562",
#         "price": 395000,
#         "size": 118,
#         "url": "https://www.idealista.pt/en/imovel/30632562/"
#     },
#     "30632589": {
#         "address": "T5 flat, Av. Estados Unidos da Am\u00e9rica, Alvalade, Alvalade",
#         "id": "30632589",
#         "price": 1200000,
#         "size": 350,
#         "url": "https://www.idealista.pt/en/imovel/30632589/"
#     },
#     "30632620": {
#         "address": "Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30632620",
#         "price": 549900,
#         "size": 148,
#         "url": "https://www.idealista.pt/en/imovel/30632620/"
#     },
#     "30632700": {
#         "address": "Alto%20de%20S%C3%A3o%20Jo%C3%A3o%20-%20Alto%20do%20Varej%C3%A3o%2C%20Penha%20de%20Fran%C3%A7a",
#         "geo": {
#             "latitude": 38.7231078,
#             "longitude": -9.114372
#         },
#         "id": "30632700",
#         "price": 590000,
#         "size": 152,
#         "url": "https://www.idealista.pt/en/imovel/30632700/"
#     },
#     "30632710": {
#         "address": "Anjos%2C%20Arroios",
#         "geo": {
#             "latitude": 38.7259608,
#             "longitude": -9.1332265
#         },
#         "id": "30632710",
#         "price": 420000,
#         "size": 111,
#         "url": "https://www.idealista.pt/en/imovel/30632710/"
#     },
#     "30632768": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30632768",
#         "price": 799000,
#         "size": 200,
#         "url": "https://www.idealista.pt/en/imovel/30632768/"
#     },
#     "30632779": {
#         "address": "T2 flat, Parque dos pr\u00edncipes _Lumiar, Telheiras, Lumiar",
#         "id": "30632779",
#         "price": 405000,
#         "size": 111,
#         "url": "https://www.idealista.pt/en/imovel/30632779/"
#     },
#     "30632873": {
#         "address": "Alto%20de%20S%C3%A3o%20Jo%C3%A3o%20-%20Alto%20do%20Varej%C3%A3o%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30632873",
#         "price": 590000,
#         "size": 152,
#         "url": "https://www.idealista.pt/en/imovel/30632873/"
#     },
#     "30632909": {
#         "address": "S%C3%A3o%20Jos%C3%A9%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30632909",
#         "price": 650000,
#         "size": 121,
#         "url": "https://www.idealista.pt/en/imovel/30632909/"
#     },
#     "30632911": {
#         "address": "S%C3%A3o%20Mamede%2C%20Santo%20Ant%C3%B3nio",
#         "id": "30632911",
#         "price": 910000,
#         "size": 125,
#         "url": "https://www.idealista.pt/en/imovel/30632911/"
#     },
#     "30632920": {
#         "address": "T3 flat, Escadinhas de Damasceno Monteiro, 95, Gra\u00e7a, S\u00e3o Vicente",
#         "id": "30632920",
#         "price": 675000,
#         "size": 143,
#         "url": "https://www.idealista.pt/en/imovel/30632920/"
#     },
#     "30632929": {
#         "address": "Bairro%20Azul%20-%20Parque%20Eduardo%20VII%2C%20Avenidas%20Novas",
#         "id": "30632929",
#         "price": 640000,
#         "size": 125,
#         "url": "https://www.idealista.pt/en/imovel/30632929/"
#     },
#     "30632931": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30632931",
#         "price": 1990000,
#         "size": 284,
#         "url": "https://www.idealista.pt/en/imovel/30632931/"
#     },
#     "30632997": {
#         "address": "Campo%20Pequeno%20-%20Nossa%20Senhora%20de%20F%C3%A1tima%2C%20Avenidas%20Novas",
#         "id": "30632997",
#         "price": 950000,
#         "size": 200,
#         "url": "https://www.idealista.pt/en/imovel/30632997/"
#     },
#     "30632999": {
#         "address": "Lapa%2C%20Estrela",
#         "id": "30632999",
#         "price": 2850000,
#         "size": 414,
#         "url": "https://www.idealista.pt/en/imovel/30632999/"
#     },
#     "30633001": {
#         "address": "Centro%20-%20Nova%20Campolide%2C%20Campolide",
#         "id": "30633001",
#         "price": 675000,
#         "size": 140,
#         "url": "https://www.idealista.pt/en/imovel/30633001/"
#     },
#     "30633159": {
#         "address": "rua%20Helena%20Vaz%20da%20Silva%2C%205%2C%20Alto%20do%20Lumiar%2C%20Lumiar",
#         "id": "30633159",
#         "price": 475000,
#         "size": 136,
#         "url": "https://www.idealista.pt/en/imovel/30633159/"
#     },
#     "30633266": {
#         "address": "Lapa%2C%20Estrela",
#         "id": "30633266",
#         "price": 525000,
#         "size": 115,
#         "url": "https://www.idealista.pt/en/imovel/30633266/"
#     },
#     "30633303": {
#         "address": "Pedrou%C3%A7os%2C%20Bel%C3%A9m",
#         "id": "30633303",
#         "price": 950000,
#         "size": 289,
#         "url": "https://www.idealista.pt/en/imovel/30633303/"
#     },
#     "30633399": {
#         "address": "Ajuda%2C%20Lisboa",
#         "id": "30633399",
#         "price": 630000,
#         "size": 147,
#         "url": "https://www.idealista.pt/en/imovel/30633399/"
#     },
#     "30633481": {
#         "address": "S%C3%A3o%20Jo%C3%A3o%20de%20Brito%2C%20Alvalade",
#         "geo": {
#             "latitude": 38.747723,
#             "longitude": -9.141767
#         },
#         "id": "30633481",
#         "price": 495000,
#         "size": 145,
#         "url": "https://www.idealista.pt/en/imovel/30633481/"
#     },
#     "30633505": {
#         "address": "rua%20Sebasti%C3%A3o%20Saraiva%20e%20Silva%2C%20Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30633505",
#         "price": 549900,
#         "size": 148,
#         "url": "https://www.idealista.pt/en/imovel/30633505/"
#     },
#     "30633634": {
#         "address": "Alto%20de%20S%C3%A3o%20Jo%C3%A3o%20-%20Alto%20do%20Varej%C3%A3o%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30633634",
#         "price": 289000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30633634/"
#     },
#     "30633668": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30633668",
#         "price": 967000,
#         "size": 156,
#         "url": "https://www.idealista.pt/en/imovel/30633668/"
#     },
#     "30633774": {
#         "address": "avenida%2024%20de%20Julho%2C%20NN%2C%20Cais%20do%20Sodr%C3%A9%20-%20S%C3%A3o%20Paulo%2C%20Miseric%C3%B3rdia",
#         "id": "30633774",
#         "price": 1138500,
#         "size": 154,
#         "url": "https://www.idealista.pt/en/imovel/30633774/"
#     },
#     "30633777": {
#         "address": "avenida%2024%20de%20Julho%2C%20NN%2C%20Cais%20do%20Sodr%C3%A9%20-%20S%C3%A3o%20Paulo%2C%20Miseric%C3%B3rdia",
#         "id": "30633777",
#         "price": 1650000,
#         "size": 153,
#         "url": "https://www.idealista.pt/en/imovel/30633777/"
#     },
#     "30633966": {
#         "address": "Telheiras%2C%20Lumiar",
#         "id": "30633966",
#         "price": 375000,
#         "size": 108,
#         "url": "https://www.idealista.pt/en/imovel/30633966/"
#     },
#     "30633995": {
#         "address": "rua%20Giovanni%20Antinori%2C%20NN%2C%20Ajuda%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7061211,
#             "longitude": -9.1917374
#         },
#         "id": "30633995",
#         "price": 523950,
#         "size": 150,
#         "url": "https://www.idealista.pt/en/imovel/30633995/"
#     },
#     "30634007": {
#         "address": "T2 flat, Pra\u00e7a da Viscondessa dos Olivais, NN, Olivais, Lisboa",
#         "geo": {
#             "latitude": 38.7684662,
#             "longitude": -9.1062486
#         },
#         "id": "30634007",
#         "price": 580000,
#         "size": 126,
#         "url": "https://www.idealista.pt/en/imovel/30634007/"
#     },
#     "30634032": {
#         "address": "rua%20Professor%20Jorge%20da%20Silva%20Horta%2C%20NN%2C%20Bairro%20de%20Santa%20Cruz%2C%20Benfica",
#         "id": "30634032",
#         "price": 625000,
#         "size": 175,
#         "url": "https://www.idealista.pt/en/imovel/30634032/"
#     },
#     "30634105": {
#         "address": "rua%20Cais%20do%20Tojo%2C%20NN%2C%20Cais%20do%20Sodr%C3%A9%20-%20S%C3%A3o%20Paulo%2C%20Miseric%C3%B3rdia",
#         "id": "30634105",
#         "price": 650000,
#         "size": 4791,
#         "url": "https://www.idealista.pt/en/imovel/30634105/"
#     },
#     "30634116": {
#         "address": "Bairro%20Alto%20-%20Encarna%C3%A7%C3%A3o%2C%20Miseric%C3%B3rdia",
#         "id": "30634116",
#         "price": 450000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30634116/"
#     },
#     "30634126": {
#         "address": "Campo%20Grande%2C%20Alvalade",
#         "id": "30634126",
#         "price": 350000,
#         "size": 112,
#         "url": "https://www.idealista.pt/en/imovel/30634126/"
#     },
#     "30634136": {
#         "address": "passeio%20%C3%82ncoras%2C%20Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30634136",
#         "price": 799000,
#         "size": 302,
#         "url": "https://www.idealista.pt/en/imovel/30634136/"
#     },
#     "30634154": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30634154",
#         "price": 335000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30634154/"
#     },
#     "30634165": {
#         "address": "Ajuda%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7033417,
#             "longitude": -9.1949708
#         },
#         "id": "30634165",
#         "price": 210000,
#         "size": 111,
#         "url": "https://www.idealista.pt/en/imovel/30634165/"
#     },
#     "30634206": {
#         "address": "Baixa%2C%20Santa%20Maria%20Maior",
#         "id": "30634206",
#         "price": 1057000,
#         "size": 151,
#         "url": "https://www.idealista.pt/en/imovel/30634206/"
#     },
#     "30634246": {
#         "address": "avenida%20do%20Brasil%2C%20S%C3%A3o%20Jo%C3%A3o%20de%20Brito%2C%20Alvalade",
#         "id": "30634246",
#         "price": 535000,
#         "size": 129,
#         "url": "https://www.idealista.pt/en/imovel/30634246/"
#     },
#     "30634277": {
#         "address": "rua%20Engenheiro%20Vieira%20da%20Silva%2C%20NN%2C%20Saldanha%20-%20Picoas%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30634277",
#         "price": 1200000,
#         "size": 288,
#         "url": "https://www.idealista.pt/en/imovel/30634277/"
#     },
#     "30634281": {
#         "address": "rua%20Virg%C3%ADlio%20Martinho%2C%20Carnide%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7644157,
#             "longitude": -9.1770357
#         },
#         "id": "30634281",
#         "price": 395000,
#         "size": 149,
#         "url": "https://www.idealista.pt/en/imovel/30634281/"
#     },
#     "30634291": {
#         "address": "Carriche%2C%20Lumiar",
#         "id": "30634291",
#         "price": 189000,
#         "size": 100490,
#         "url": "https://www.idealista.pt/en/imovel/30634291/"
#     },
#     "30634296": {
#         "address": "rua%20de%20S%C3%A3o%20Jo%C3%A3o%20da%20Pra%C3%A7a%2C%20NN%2C%20Alfama%20-%20S%C3%A9%2C%20Santa%20Maria%20Maior",
#         "geo": {
#             "latitude": 38.7098424,
#             "longitude": -9.1303002
#         },
#         "id": "30634296",
#         "price": 375000,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30634296/"
#     },
#     "30634316": {
#         "address": "rua%20Francisco%20de%20Andrade%2C%20Alvalade%2C%20Alvalade",
#         "id": "30634316",
#         "price": 899900,
#         "size": 200,
#         "url": "https://www.idealista.pt/en/imovel/30634316/"
#     },
#     "30634330": {
#         "address": "Alfama%20-%20S%C3%A9%2C%20Santa%20Maria%20Maior",
#         "id": "30634330",
#         "price": 750000,
#         "size": 180,
#         "url": "https://www.idealista.pt/en/imovel/30634330/"
#     },
#     "30634345": {
#         "address": "estrada%20de%20Benfica%2C%20NN%2C%20Arneiros%20-%20Avenida%20Uruguai%20-%20Charquinho%2C%20Benfica",
#         "id": "30634345",
#         "price": 799000,
#         "size": 160,
#         "url": "https://www.idealista.pt/en/imovel/30634345/"
#     },
#     "30634367": {
#         "address": "rua%20Cidade%20de%20Bolama%2C%20NN%2C%20Olivais%2C%20Lisboa",
#         "id": "30634367",
#         "price": 499000,
#         "size": 144,
#         "url": "https://www.idealista.pt/en/imovel/30634367/"
#     },
#     "30634415": {
#         "address": "rua%20Cidade%20da%20Beira%2C%20NN%2C%20Olivais%2C%20Lisboa",
#         "id": "30634415",
#         "price": 362500,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30634415/"
#     },
#     "30634423": {
#         "address": "rua%20Professor%20Vieira%20de%20Almeida%2C%20NN%2C%20Telheiras%2C%20Lumiar",
#         "geo": {
#             "latitude": 38.7634423,
#             "longitude": -9.1669539
#         },
#         "id": "30634423",
#         "price": 367900,
#         "size": 109,
#         "url": "https://www.idealista.pt/en/imovel/30634423/"
#     },
#     "30634472": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "geo": {
#             "latitude": 38.7537331,
#             "longitude": -9.1703635
#         },
#         "id": "30634472",
#         "price": 540000,
#         "size": 137,
#         "url": "https://www.idealista.pt/en/imovel/30634472/"
#     },
#     "30634643": {
#         "address": "Bairro%20Azul%20-%20Parque%20Eduardo%20VII%2C%20Avenidas%20Novas",
#         "id": "30634643",
#         "price": 1200000,
#         "size": 248,
#         "url": "https://www.idealista.pt/en/imovel/30634643/"
#     },
#     "30634694": {
#         "address": "estrada%20de%20Chelas%2C%20Alto%20de%20S%C3%A3o%20Jo%C3%A3o%20-%20Alto%20do%20Varej%C3%A3o%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30634694",
#         "price": 289000,
#         "size": 100,
#         "url": "https://www.idealista.pt/en/imovel/30634694/"
#     },
#     "30634717": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30634717",
#         "price": 559000,
#         "size": 148,
#         "url": "https://www.idealista.pt/en/imovel/30634717/"
#     },
#     "30634724": {
#         "address": "Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30634724",
#         "price": 549900,
#         "size": 143,
#         "url": "https://www.idealista.pt/en/imovel/30634724/"
#     },
#     "30634743": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30634743",
#         "price": 685000,
#         "size": 135,
#         "url": "https://www.idealista.pt/en/imovel/30634743/"
#     },
#     "30634833": {
#         "address": "House, Pra\u00e7a Professor Rodrigues Lapa, 114, Telheiras, Lumiar",
#         "id": "30634833",
#         "price": 520000,
#         "size": 204,
#         "url": "https://www.idealista.pt/en/imovel/30634833/"
#     },
#     "30634973": {
#         "address": "Carriche%2C%20Lumiar",
#         "id": "30634973",
#         "price": 280000,
#         "size": 120,
#         "url": "https://www.idealista.pt/en/imovel/30634973/"
#     },
#     "30635123": {
#         "address": "Parque%20das%20Na%C3%A7%C3%B5es%2C%20Lisboa",
#         "id": "30635123",
#         "price": 575000,
#         "size": 122,
#         "url": "https://www.idealista.pt/en/imovel/30635123/"
#     },
#     "30635277": {
#         "address": "Prazeres%2C%20Estrela",
#         "id": "30635277",
#         "price": 525000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30635277/"
#     },
#     "30635282": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30635282",
#         "price": 785000,
#         "size": 118,
#         "url": "https://www.idealista.pt/en/imovel/30635282/"
#     },
#     "30635425": {
#         "address": "alameda%20Dom%20Afonso%20Henriques%2C%20Alameda%20-%20Pra%C3%A7a%20do%20Chile%20-%20Almirante%20Reis%2C%20S%C3%A3o%20Jorge%20de%20Arroios%2C%20Arroios",
#         "id": "30635425",
#         "price": 900000,
#         "size": 230,
#         "url": "https://www.idealista.pt/en/imovel/30635425/"
#     },
#     "30635426": {
#         "address": "Bairro%20Azul%20-%20Parque%20Eduardo%20VII%2C%20Avenidas%20Novas",
#         "id": "30635426",
#         "price": 695000,
#         "size": 175,
#         "url": "https://www.idealista.pt/en/imovel/30635426/"
#     },
#     "30635487": {
#         "address": "Centro%2C%20Penha%20de%20Fran%C3%A7a",
#         "id": "30635487",
#         "price": 175000,
#         "size": 105,
#         "url": "https://www.idealista.pt/en/imovel/30635487/"
#     },
#     "30635511": {
#         "address": "rua%20Abranches%20Ferr%C3%A3o%2C%20S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30635511",
#         "price": 725000,
#         "size": 204,
#         "url": "https://www.idealista.pt/en/imovel/30635511/"
#     },
#     "30635547": {
#         "address": "Duplex, Av. Estados Unidos da Am\u00e9rica, Alvalade, Alvalade",
#         "id": "30635547",
#         "price": 430000,
#         "size": 126,
#         "url": "https://www.idealista.pt/en/imovel/30635547/"
#     },
#     "30635640": {
#         "address": "Beato%2C%20Lisboa",
#         "id": "30635640",
#         "price": 399000,
#         "size": 131,
#         "url": "https://www.idealista.pt/en/imovel/30635640/"
#     },
#     "30635642": {
#         "address": "avenida%20Ant%C3%B3nio%20Augusto%20de%20Aguiar%2C%20140%2C%20Bairro%20Azul%20-%20Parque%20Eduardo%20VII%2C%20Avenidas%20Novas",
#         "id": "30635642",
#         "price": 1100000,
#         "size": 154,
#         "url": "https://www.idealista.pt/en/imovel/30635642/"
#     },
#     "30635661": {
#         "address": "Campo%20Grande%2C%20Alvalade",
#         "id": "30635661",
#         "price": 410000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30635661/"
#     },
#     "30635809": {
#         "address": "Bairro%20Alto%20-%20Encarna%C3%A7%C3%A3o%2C%20Miseric%C3%B3rdia",
#         "id": "30635809",
#         "price": 986000,
#         "size": 145,
#         "url": "https://www.idealista.pt/en/imovel/30635809/"
#     },
#     "30635813": {
#         "address": "Castelo%20-%20Mouraria%2C%20Santa%20Maria%20Maior",
#         "id": "30635813",
#         "price": 525000,
#         "size": 110,
#         "url": "https://www.idealista.pt/en/imovel/30635813/"
#     },
#     "30635814": {
#         "address": "Anjos%2C%20Arroios",
#         "id": "30635814",
#         "price": 780000,
#         "size": 275,
#         "url": "https://www.idealista.pt/en/imovel/30635814/"
#     },
#     "30635867": {
#         "address": "Areeiro%2C%20Lisboa",
#         "id": "30635867",
#         "price": 699000,
#         "size": 168,
#         "url": "https://www.idealista.pt/en/imovel/30635867/"
#     },
#     "30635879": {
#         "address": "Telheiras%2C%20Lumiar",
#         "id": "30635879",
#         "price": 485000,
#         "size": 130,
#         "url": "https://www.idealista.pt/en/imovel/30635879/"
#     },
#     "30635936": {
#         "address": "Alvalade%2C%20Alvalade",
#         "id": "30635936",
#         "price": 1050000,
#         "size": 152,
#         "url": "https://www.idealista.pt/en/imovel/30635936/"
#     },
#     "30635938": {
#         "address": "S%C3%A3o%20Jo%C3%A3o%20de%20Brito%2C%20Alvalade",
#         "id": "30635938",
#         "price": 1750000,
#         "size": 800,
#         "url": "https://www.idealista.pt/en/imovel/30635938/"
#     },
#     "30635991": {
#         "address": "Santa%20Clara%2C%20Lisboa",
#         "id": "30635991",
#         "price": 395000,
#         "size": 166,
#         "url": "https://www.idealista.pt/en/imovel/30635991/"
#     },
#     "30636011": {
#         "address": "Anjos%2C%20Arroios",
#         "id": "30636011",
#         "price": 570000,
#         "size": 196,
#         "url": "https://www.idealista.pt/en/imovel/30636011/"
#     },
#     "30636047": {
#         "address": "Anjos%2C%20Arroios",
#         "id": "30636047",
#         "price": 1600000,
#         "size": 252,
#         "url": "https://www.idealista.pt/en/imovel/30636047/"
#     },
#     "30636056": {
#         "address": "Alc%C3%A2ntara%2C%20Lisboa",
#         "id": "30636056",
#         "price": 580000,
#         "size": 138,
#         "url": "https://www.idealista.pt/en/imovel/30636056/"
#     },
#     "30636076": {
#         "address": "S%C3%A3o%20Domingos%20de%20Benfica%2C%20Lisboa",
#         "id": "30636076",
#         "price": 875000,
#         "size": 205,
#         "url": "https://www.idealista.pt/en/imovel/30636076/"
#     },
#     "30636107": {
#         "address": "Campo%20de%20Ourique%2C%20Lisboa",
#         "id": "30636107",
#         "price": 535000,
#         "size": 124,
#         "url": "https://www.idealista.pt/en/imovel/30636107/"
#     },
#     "30636309": {
#         "address": "rua%20Professor%20Sim%C3%B5es%20Raposo%2C%20Telheiras%2C%20Lumiar",
#         "id": "30636309",
#         "price": 595000,
#         "size": 158,
#         "url": "https://www.idealista.pt/en/imovel/30636309/"
#     }
# }
